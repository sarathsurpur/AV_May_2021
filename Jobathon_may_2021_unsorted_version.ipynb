# %% [markdown]
# # Problem Statement
#
# Credit Card Lead Prediction
# Happy Customer Bank is a mid-sized private bank that deals in all kinds of banking products, like Savings accounts, Current accounts, investment products, credit products, among other offerings.
#
#
#
# The bank also cross-sells products to its existing customers and to do so they use different kinds of communication like tele-calling, e-mails, recommendations on net banking, mobile banking, etc.
#
#
#
# In this case, the Happy Customer Bank wants to cross sell its credit cards to its existing customers. The bank has identified a set of customers that are eligible for taking these credit cards.
#
#
#
# Now, the bank is looking for your help in identifying customers that could show higher intent towards a recommended credit card, given:
#
# Customer details (gender, age, region etc.)
# Details of his/her relationship with the bank (Channel_Code,Vintage, 'Avg_Asset_Value etc.)
#
#
# Data Dictionary
#
# Train Data
#
# |Variable|Definition|
# |--------|----------|
# |ID|Unique Identifier for a row|
# |Gender|Gender of the Customer|
# |Age|Age of the Customer (in Years)|
# |Region_Code|Code of the Region for the customers|
# |Occupation|Occupation Type for the customer|
# |Channel_Code|Acquisition Channel Code for the Customer  (Encoded)|
# |Vintage|Vintage for the Customer (In Months)|
# |Credit_Product|If the Customer has any active credit product (Home loan,Personal loan, Credit Card etc.)|
# |Avg_Account_Balance|Average Account Balance for the Customer in last 12 Months|
# |Is_Active|If the Customer is Active in last 3 Months|
# |Is_Lead(Target)|If the Customer is interested for the Credit Card 0 : Customer is not interested 1 : Customer is interested|
#
#
# Test Data
#
# |Variable|Definition|
# |--------|----------|
# |ID|Unique Identifier for a row|
# |Gender|Gender of the Customer|
# |Age|Age of the Customer (in Years)|
# |Region_Code|Code of the Region for the customers|
# |Occupation|Occupation Type for the customer|
# |Channel_Code|Acquisition Channel Code for the Customer  (Encoded)|
# |Vintage|Vintage for the Customer (In Months)|
# |Credit_Product|If the Customer has any active credit product (Home loan,Personal loan, Credit Card etc.)|
# |Avg_Account_Balance|Average Account Balance for the Customer in last 12 Months|
# |Is_Active|If the Customer is Active in last 3 Months|
#
# Sample Submission
# This file contains the exact submission format for the predictions. Please submit CSV file only.
#
# |Variable|	Definition|
# |--------|------------|
# |ID|	Unique Identifier for a row|
# |Is_Lead	(Target)| Probability of Customer showing interest (class 1)|

# %%
# !pip install pycaret
# !pip install catboost
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import matthews_corrcoef as mcc
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import KBinsDiscretizer
import xgboost as xgb
from tqdm import tqdm_notebook
from sklearn.metrics import roc_curve,precision_recall_curve
from catboost import Pool, cv, CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate
rf_model = RandomForestClassifier(class_weight='balanced')
import lightgbm as lgb
from sklearn.cluster import KMeans
from scipy.stats import kurtosis, iqr
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %% [markdown]
# CONFIG

# %%
DATA_PATH = '/content/drive/MyDrive/Jobathon_may_2021/'
TRAIN_PATH = DATA_PATH + 'train.csv'
TEST_PATH = DATA_PATH + 'test.csv'

CATEGORICAL_COL = ['GENDER','REGION_CODE', 'OCCUPATION','CHANNEL_CODE',\
                   'CREDIT_PRODUCT','IS_ACTIVE']

# %% [markdown]
# UTIL FUNCTIONS

# %%
def evaluate_model(y_true, y_pred):
  # print('CLASSIFICATION REPORT')
  # print('***************************')
  # print(classification_report(y_true,y_pred))
  # print('CONFUSION MATRIX')
  # print('****************************')
  # cm = confusion_matrix(y_true, y_pred)
  # cm_df = pd.DataFrame(cm.T, index=[0,1], columns=[0,1])
  # cm_df.index.name = 'Predicted'
  # cm_df.columns.name = 'True'
  # print(cm_df)
  # print('MATHEW CORRELATION COEFF')
  # print('***************************')
  # print( mcc(y_true, y_pred))
  print('ROC_AUC')
  print('***************************')
  print(roc_auc_score(y_true,y_pred))

def upper_case_columns(df):
  '''
  Convert case of columns in dataframe
  '''
  df.columns = [x.upper() for x in df.columns]
  return df


def miss_data(df):
  '''
  To summarise details of missing values in a dataframe
  '''
  x = ['column_name','missing_data', 'missing_in_percentage']
  missing_data = pd.DataFrame(columns=x)
  columns = df.columns
  for col in columns:
      icolumn_name = col
      imissing_data = df[col].isnull().sum()
      imissing_in_percentage = (df[col].isnull().sum()/df[col].shape[0])*100

      missing_data.loc[len(missing_data)] = [icolumn_name, imissing_data, imissing_in_percentage]
  print(missing_data)

def split(df):
  x_train, x_val, y_train, y_val = train_test_split(df.drop(['IS_LEAD','IS_TRAIN','ID','KFOLD'], axis=1), \
                                                  df['IS_LEAD'].astype('int'),
                                                    test_size=0.20,shuffle=True,
                                                    random_state=0,
                                                    stratify=df['IS_LEAD'])
  return x_train, x_val, y_train, y_val

# %% [markdown]
# ANALYSIS

# %%
train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)

# change column case
train = upper_case_columns(train)
test = upper_case_columns(test)

# %%
# splitting data in to 5 folds

train['KFOLD'] = -1

kf = StratifiedKFold(n_splits=5)

for f, (train_idx, valid_idx) in enumerate(kf.split(X = train, y = train['IS_LEAD'].values)):
  train.loc[valid_idx,'KFOLD'] = f

# %%
print('Number of records in train set', train.shape[0])
print('Number of records in test set', test.shape[0])
# Out:
# Number of records in train set 245725
# Number of records in test set 105312

# %%
# check target column distribution
train['IS_LEAD'].value_counts(normalize=True)
# Out:
# 0    0.762792
# 1    0.237208
# Name: IS_LEAD, dtype: float64

# %% [markdown]
# Target class distribution is skewed with 75% of data belonging to the class 0

# %%
miss_data(train), miss_data(test)
# Out:
#             column_name missing_data  missing_in_percentage
# 0                    ID            0               0.000000
# 1                GENDER            0               0.000000
# 2                   AGE            0               0.000000
# 3           REGION_CODE            0               0.000000
# 4            OCCUPATION            0               0.000000
# 5          CHANNEL_CODE            0               0.000000
# 6               VINTAGE            0               0.000000
# 7        CREDIT_PRODUCT        29325              11.934073
# 8   AVG_ACCOUNT_BALANCE            0               0.000000
# 9             IS_ACTIVE            0               0.000000
# 10              IS_LEAD            0               0.000000
# 11                KFOLD            0               0.000000
#            column_name missing_data  missing_in_percentage
# 0                   ID            0               0.000000
# 1               GENDER            0               0.000000
# 2                  AGE            0               0.000000
# 3          REGION_CODE            0               0.000000
# 4           OCCUPATION            0               0.000000
# 5         CHANNEL_CODE            0               0.000000
# 6              VINTAGE            0               0.000000
# 7       CREDIT_PRODUCT        12522              11.890383
# 8  AVG_ACCOUNT_BALANCE            0               0.000000
# 9            IS_ACTIVE            0               0.000000
# (None, None)

# %% [markdown]
# Only credit product has 11% of missing values in both train and test set

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245725 entries, 0 to 245724
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   245725 non-null  object
#  1   GENDER               245725 non-null  object
#  2   AGE                  245725 non-null  int64
#  3   REGION_CODE          245725 non-null  object
#  4   OCCUPATION           245725 non-null  object
#  5   CHANNEL_CODE         245725 non-null  object
#  6   VINTAGE              245725 non-null  int64
#  7   CREDIT_PRODUCT       216400 non-null  object
#  8   AVG_ACCOUNT_BALANCE  245725 non-null  int64
#  9   IS_ACTIVE            245725 non-null  object
#  10  IS_LEAD              245725 non-null  int64
#  11  KFOLD                245725 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 22.5+ MB

# %% [markdown]
# In the dataset, 3 continuous columns are available and rest are categorical columns

# %%
print('Number of unique elements in each column')
print('******************************************')
for i in train.columns:
  uniq = train[i].nunique()
  print(f'{i}: {uniq}')
# Out:
# Number of unique elements in each column
# ******************************************
# ID: 245725
# GENDER: 2
# AGE: 63
# REGION_CODE: 35
# OCCUPATION: 4
# CHANNEL_CODE: 4
# VINTAGE: 66
# CREDIT_PRODUCT: 2
# AVG_ACCOUNT_BALANCE: 135292
# IS_ACTIVE: 2
# IS_LEAD: 2
# KFOLD: 5

# %% [markdown]
# ID is a unique element in the dataset. Age column is continous with only 63 different values and Vintage column is continous with only 66 different values

# %% [markdown]
# EDA

# %%
def col_plot(train, col):
  fig, ax = plt.subplots(1, 2, figsize=(14, 4))
  train[train['IS_LEAD'] == 0][col].value_counts(normalize=True).plot(kind='bar',ax=ax[0]).set_title('NOT INTERESTED')
  train[train['IS_LEAD'] == 1][col].value_counts(normalize=True).plot(kind='bar',ax=ax[1]).set_title('INTERESTED')
  plt.suptitle(col)
  plt.show()

# %%
for i in CATEGORICAL_COL:
  col_plot(train,i)

# %% [markdown]
# Dealing with MISSING values and Categorical columns

# %%
# missing values are available only in credit product column

train['CREDIT_PRODUCT'].fillna('None', inplace=True)
test['CREDIT_PRODUCT'].fillna('None', inplace=True)

# encoder = LabelEncoder()

# for c in CATEGORICAL_COL:
#     train[c] = encoder.fit_transform(train[c])
#     test[c] = encoder.transform(test[c])

# %%
CAT_IND = x_train.columns.get_indexer(CATEGORICAL_COL)
params = {"iterations": 100,
          "loss_function": "Logloss",
          'custom_metric':'AUC',
          'class_weights':[3,4],
          "verbose": False}

cv_data = Pool(data=x_train,
                  label=y_train,
                  cat_features=CAT_IND)

scores = cv(cv_data,
            params,
            fold_count=5, shuffle=False)

# %%
xg = xgb.XGBClassifier(random_state=0, scale_pos_weight=3)
xg.fit(x_train, y_train, eval_set=[(x_val,y_val)], eval_metric='auc')

# %%
encoder = LabelEncoder()

for c in CATEGORICAL_COL:
    train[c] = encoder.fit_transform(train[c])
    test[c] = encoder.transform(test[c])

# %%
train['AVG_ACCOUNT_BALANCE'] = np.log(train['AVG_ACCOUNT_BALANCE'])
test['AVG_ACCOUNT_BALANCE'] = np.log(test['AVG_ACCOUNT_BALANCE'])

# %%
test_pred = []
thresh = []
for i in tqdm_notebook(range(5)):
  x_train = train[train['KFOLD']!=i].drop(['ID','IS_LEAD','IS_TRAIN','KFOLD'], axis=1)
  y_train = train[train['KFOLD']!=i]['IS_LEAD']
  x_val = train[train['KFOLD']==i].drop(['ID','IS_LEAD','IS_TRAIN','KFOLD'], axis=1)
  y_val = train[train['KFOLD']==i]['IS_LEAD']

  # creating model
  model_lgbm  = lgb.LGBMClassifier(class_weight = 'balanced',
                                 objective = 'binary', 
                                 silent=True,
                                 iterations = 200,
                                 boosting_type = 'gbdt',
                                 bagging_fraction = 0.83,
                                 feature_fraction = 0.84,
                                lambda_l1 = 2,
                                # lambda_l2 = 2.37,
                                # learning_rate = 0.011,
                                # max_depth = 12,
                                min_child_weight = 4,
                                # min_split_gain = 0.04,
                                num_leaves = 201,
                                subsample = 0.25,
                                 min_data_in_leaf=307, 
                                 max_depth=7, 
                                 learning_rate=0.1)
  
  cat = CatBoostClassifier(class_weights=[1,3],
                           iterations = 200,
                           learning_rate = 0.06,
                           depth = 8,
                           l2_leaf_reg = 21, 
                           eval_metric='AUC', 
                           silent=True)
  CAT_IND = x_train.columns.get_indexer(CATEGORICAL_COL)

  model_lgbm.fit(x_train, y_train, categorical_feature = CATEGORICAL_COL, 
                 eval_metric='auc', eval_set=[(x_val,y_val)])
  cat.fit(x_train, y_train, cat_features=CAT_IND, eval_set = [(x_val, y_val)])

  val_pred1 = model_lgbm.predict_proba(x_val)[:,1]
  val_pred2 = cat.predict_proba(x_val)[:,1]
 
  val_pred = 0.6*val_pred1 + 0.4*val_pred2
  print(evaluate_model(y_val, val_pred))
  pred1 = model_lgbm.predict_proba(test[x_train.columns])[:,1]
  pred2 = cat.predict_proba(test[x_train.columns])[:,1]
  pred = 0.6*pred1 + 0.4*pred2
  test_pred.append(pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['AGE_BIN', 'CHANNEL_CODE', 'CREDIT_PRODUCT', 'GENDER', 'IS_ACTIVE', 'OCCUPATION', 'REGION_CODE', 'VINTAGE_BIN']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [1]	valid_0's auc: 0.86438	valid_0's binary_logloss: 0.652738
# [2]	valid_0's auc: 0.865697	valid_0's binary_logloss: 0.619802
# [3]	valid_0's auc: 0.868454	valid_0's binary_logloss: 0.591208
# [4]	valid_0's auc: 0.86913	valid_0's binary_logloss: 0.567482
# [5]	valid_0's auc: 0.869036	valid_0's binary_logloss: 0.547724
# [6]	valid_0's auc: 0.86967	valid_0's binary_logloss: 0.530663
# [7]	valid_0's auc: 0.869906	valid_0's binary_logloss: 0.516289
# [8]	valid_0's auc: 0.869893	valid_0's binary_logloss: 0.504016
# [9]	valid_0's auc: 0.869843	valid_0's binary_logloss: 0.493318
# [10]	valid_0's auc: 0.870038	valid_0's binary_logloss: 0.484577
# [11]	valid_0's auc: 0.870098	valid_0's binary_logloss: 0.476903
# [12]	valid_0's auc: 0.869915	valid_0's binary_logloss: 0.470584
# [13]	valid_0's auc: 0.870114	valid_0's binary_logloss: 0.4673
# [14]	valid_0's auc: 0.869965	valid_0's binary_logloss: 0.462245
# [15]	valid_0's auc: 0.869998	valid_0's binary_logloss: 0.457587
# [16]	valid_0's auc: 0.870477	valid_0's binary_logloss: 0.453251
# [17]	valid_0's auc: 0.870755	valid_0's binary_logloss: 0.449498
# [18]	valid_0's auc: 0.871	valid_0's binary_logloss: 0.446158
# [19]	valid_0's auc: 0.87089	valid_0's binary_logloss: 0.4438
# [20]	valid_0's auc: 0.870939	valid_0's binary_logloss: 0.441284
# [21]	valid_0's auc: 0.871153	valid_0's binary_logloss: 0.439019
# [22]	valid_0's auc: 0.871313	valid_0's binary_logloss: 0.437142
# [23]	valid_0's auc: 0.871327	valid_0's binary_logloss: 0.435631
# [24]	valid_0's auc: 0.871288	valid_0's binary_logloss: 0.43454
# [25]	valid_0's auc: 0.871432	valid_0's binary_logloss: 0.43319
# [26]	valid_0's auc: 0.871535	valid_0's binary_logloss: 0.432467
# [27]	valid_0's auc: 0.871617	valid_0's binary_logloss: 0.431405
# [28]	valid_0's auc: 0.871582	valid_0's binary_logloss: 0.430803
# [29]	valid_0's auc: 0.871644	valid_0's binary_logloss: 0.429924
# [30]	valid_0's auc: 0.871625	valid_0's binary_logloss: 0.429755
# [31]	valid_0's auc: 0.871623	valid_0's binary_logloss: 0.429034
# [32]	valid_0's auc: 0.871683	valid_0's binary_logloss: 0.42841
# [33]	valid_0's auc: 0.871766	valid_0's binary_logloss: 0.427836
# [34]	valid_0's auc: 0.871786	valid_0's binary_logloss: 0.427501
# [35]	valid_0's auc: 0.871756	valid_0's binary_logloss: 0.427228
# [36]	valid_0's auc: 0.871819	valid_0's binary_logloss: 0.426746
# [37]	valid_0's auc: 0.871829	valid_0's binary_logloss: 0.426378
# [38]	valid_0's auc: 0.871885	valid_0's binary_logloss: 0.426115
# [39]	valid_0's auc: 0.871913	valid_0's binary_logloss: 0.425752
# [40]	valid_0's auc: 0.871889	valid_0's binary_logloss: 0.425582
# [41]	valid_0's auc: 0.871946	valid_0's binary_logloss: 0.425378
# [42]	valid_0's auc: 0.871946	valid_0's binary_logloss: 0.425226
# [43]	valid_0's auc: 0.871961	valid_0's binary_logloss: 0.425089
# [44]	valid_0's auc: 0.871928	valid_0's binary_logloss: 0.424852
# [45]	valid_0's auc: 0.871921	valid_0's binary_logloss: 0.424669
# [46]	valid_0's auc: 0.871975	valid_0's binary_logloss: 0.424513
# [47]	valid_0's auc: 0.872007	valid_0's binary_logloss: 0.424414
# [48]	valid_0's auc: 0.872016	valid_0's binary_logloss: 0.424257
# [49]	valid_0's auc: 0.872045	valid_0's binary_logloss: 0.424122
# [50]	valid_0's auc: 0.872119	valid_0's binary_logloss: 0.424036
# [51]	valid_0's auc: 0.872134	valid_0's binary_logloss: 0.423931
# [52]	valid_0's auc: 0.872137	valid_0's binary_logloss: 0.423874
# [53]	valid_0's auc: 0.872127	valid_0's binary_logloss: 0.423778
# [54]	valid_0's auc: 0.872127	valid_0's binary_logloss: 0.423697
# [55]	valid_0's auc: 0.872127	valid_0's binary_logloss: 0.42366
# [56]	valid_0's auc: 0.872164	valid_0's binary_logloss: 0.423617
# [57]	valid_0's auc: 0.872175	valid_0's binary_logloss: 0.423542
# [58]	valid_0's auc: 0.872189	valid_0's binary_logloss: 0.423502
# [59]	valid_0's auc: 0.872203	valid_0's binary_logloss: 0.423441
# [60]	valid_0's auc: 0.872199	valid_0's binary_logloss: 0.423379
# [61]	valid_0's auc: 0.872225	valid_0's binary_logloss: 0.423357
# [62]	valid_0's auc: 0.872245	valid_0's binary_logloss: 0.423322
# [63]	valid_0's auc: 0.872256	valid_0's binary_logloss: 0.423304
# [64]	valid_0's auc: 0.872217	valid_0's binary_logloss: 0.423283
# [65]	valid_0's auc: 0.872149	valid_0's binary_logloss: 0.42328
# [66]	valid_0's auc: 0.872173	valid_0's binary_logloss: 0.423246
# [67]	valid_0's auc: 0.872147	valid_0's binary_logloss: 0.42317
# [68]	valid_0's auc: 0.872127	valid_0's binary_logloss: 0.423153
# [69]	valid_0's auc: 0.872161	valid_0's binary_logloss: 0.423088
# [70]	valid_0's auc: 0.872148	valid_0's binary_logloss: 0.423064
# [71]	valid_0's auc: 0.872124	valid_0's binary_logloss: 0.423074
# [72]	valid_0's auc: 0.872139	valid_0's binary_logloss: 0.423055
# [73]	valid_0's auc: 0.872153	valid_0's binary_logloss: 0.423018
# [74]	valid_0's auc: 0.872128	valid_0's binary_logloss: 0.423003
# [75]	valid_0's auc: 0.872177	valid_0's binary_logloss: 0.422916
# [76]	valid_0's auc: 0.872146	valid_0's binary_logloss: 0.422925
# [77]	valid_0's auc: 0.872107	valid_0's binary_logloss: 0.422933
# [78]	valid_0's auc: 0.872094	valid_0's binary_logloss: 0.422929
# [79]	valid_0's auc: 0.872063	valid_0's binary_logloss: 0.422941
# [80]	valid_0's auc: 0.872072	valid_0's binary_logloss: 0.422892
# [81]	valid_0's auc: 0.872074	valid_0's binary_logloss: 0.422859
# [82]	valid_0's auc: 0.872035	valid_0's binary_logloss: 0.422857
# [83]	valid_0's auc: 0.871978	valid_0's binary_logloss: 0.422883
# [84]	valid_0's auc: 0.871959	valid_0's binary_logloss: 0.422834
# [85]	valid_0's auc: 0.87195	valid_0's binary_logloss: 0.422812
# [86]	valid_0's auc: 0.871931	valid_0's binary_logloss: 0.422816
# [87]	valid_0's auc: 0.871903	valid_0's binary_logloss: 0.422831
# [88]	valid_0's auc: 0.871873	valid_0's binary_logloss: 0.422811
# [89]	valid_0's auc: 0.87187	valid_0's binary_logloss: 0.422794
# [90]	valid_0's auc: 0.871844	valid_0's binary_logloss: 0.422784
# [91]	valid_0's auc: 0.871826	valid_0's binary_logloss: 0.422788
# [92]	valid_0's auc: 0.871773	valid_0's binary_logloss: 0.422795
# [93]	valid_0's auc: 0.871748	valid_0's binary_logloss: 0.422774
# [94]	valid_0's auc: 0.871731	valid_0's binary_logloss: 0.422779
# [95]	valid_0's auc: 0.871723	valid_0's binary_logloss: 0.422776
# [96]	valid_0's auc: 0.871742	valid_0's binary_logloss: 0.42276
# [97]	valid_0's auc: 0.871734	valid_0's binary_logloss: 0.422745
# [98]	valid_0's auc: 0.871719	valid_0's binary_logloss: 0.422748
# [99]	valid_0's auc: 0.871703	valid_0's binary_logloss: 0.422748
# [100]	valid_0's auc: 0.871693	valid_0's binary_logloss: 0.422711
# ROC_AUC
# ***************************
# 0.8725071271327027
# None
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['AGE_BIN', 'CHANNEL_CODE', 'CREDIT_PRODUCT', 'GENDER', 'IS_ACTIVE', 'OCCUPATION', 'REGION_CODE', 'VINTAGE_BIN']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [1]	valid_0's auc: 0.864401	valid_0's binary_logloss: 0.652544
# [2]	valid_0's auc: 0.865864	valid_0's binary_logloss: 0.619643
# [3]	valid_0's auc: 0.869333	valid_0's binary_logloss: 0.590865
# [4]	valid_0's auc: 0.870056	valid_0's binary_logloss: 0.566993
# [5]	valid_0's auc: 0.870436	valid_0's binary_logloss: 0.547061
# [6]	valid_0's auc: 0.870705	valid_0's binary_logloss: 0.529911
# [7]	valid_0's auc: 0.870852	valid_0's binary_logloss: 0.515362
# [8]	valid_0's auc: 0.871115	valid_0's binary_logloss: 0.502991
# [9]	valid_0's auc: 0.871372	valid_0's binary_logloss: 0.49215
# [10]	valid_0's auc: 0.871189	valid_0's binary_logloss: 0.483424
# [11]	valid_0's auc: 0.871306	valid_0's binary_logloss: 0.475628
# [12]	valid_0's auc: 0.871051	valid_0's binary_logloss: 0.469335
# [13]	valid_0's auc: 0.871563	valid_0's binary_logloss: 0.466027
# [14]	valid_0's auc: 0.871434	valid_0's binary_logloss: 0.460965
# [15]	valid_0's auc: 0.871492	valid_0's binary_logloss: 0.456216
# [16]	valid_0's auc: 0.871774	valid_0's binary_logloss: 0.451809
# [17]	valid_0's auc: 0.872009	valid_0's binary_logloss: 0.448063
# [18]	valid_0's auc: 0.872229	valid_0's binary_logloss: 0.444671
# [19]	valid_0's auc: 0.872232	valid_0's binary_logloss: 0.44223
# [20]	valid_0's auc: 0.872356	valid_0's binary_logloss: 0.439668
# [21]	valid_0's auc: 0.872536	valid_0's binary_logloss: 0.437385
# [22]	valid_0's auc: 0.872673	valid_0's binary_logloss: 0.435494
# [23]	valid_0's auc: 0.872677	valid_0's binary_logloss: 0.434
# [24]	valid_0's auc: 0.872617	valid_0's binary_logloss: 0.432912
# [25]	valid_0's auc: 0.872762	valid_0's binary_logloss: 0.431572
# [26]	valid_0's auc: 0.872954	valid_0's binary_logloss: 0.430791
# [27]	valid_0's auc: 0.873069	valid_0's binary_logloss: 0.429685
# [28]	valid_0's auc: 0.873181	valid_0's binary_logloss: 0.429019
# [29]	valid_0's auc: 0.873231	valid_0's binary_logloss: 0.428158
# [30]	valid_0's auc: 0.873215	valid_0's binary_logloss: 0.428009
# [31]	valid_0's auc: 0.873247	valid_0's binary_logloss: 0.427298
# [32]	valid_0's auc: 0.87328	valid_0's binary_logloss: 0.426574
# [33]	valid_0's auc: 0.873273	valid_0's binary_logloss: 0.426051
# [34]	valid_0's auc: 0.87329	valid_0's binary_logloss: 0.425687
# [35]	valid_0's auc: 0.873284	valid_0's binary_logloss: 0.425393
# [36]	valid_0's auc: 0.873364	valid_0's binary_logloss: 0.424863
# [37]	valid_0's auc: 0.873389	valid_0's binary_logloss: 0.424461
# [38]	valid_0's auc: 0.87347	valid_0's binary_logloss: 0.424186
# [39]	valid_0's auc: 0.873521	valid_0's binary_logloss: 0.423877
# [40]	valid_0's auc: 0.87356	valid_0's binary_logloss: 0.423675
# [41]	valid_0's auc: 0.873578	valid_0's binary_logloss: 0.423385
# [42]	valid_0's auc: 0.873609	valid_0's binary_logloss: 0.423197
# [43]	valid_0's auc: 0.873711	valid_0's binary_logloss: 0.422974
# [44]	valid_0's auc: 0.873802	valid_0's binary_logloss: 0.422677
# [45]	valid_0's auc: 0.873808	valid_0's binary_logloss: 0.42254
# [46]	valid_0's auc: 0.873809	valid_0's binary_logloss: 0.422403
# [47]	valid_0's auc: 0.873784	valid_0's binary_logloss: 0.422322
# [48]	valid_0's auc: 0.873767	valid_0's binary_logloss: 0.422182
# [49]	valid_0's auc: 0.873806	valid_0's binary_logloss: 0.422062
# [50]	valid_0's auc: 0.873818	valid_0's binary_logloss: 0.421942
# [51]	valid_0's auc: 0.873827	valid_0's binary_logloss: 0.421831
# [52]	valid_0's auc: 0.873842	valid_0's binary_logloss: 0.421741
# [53]	valid_0's auc: 0.873837	valid_0's binary_logloss: 0.421665
# [54]	valid_0's auc: 0.873835	valid_0's binary_logloss: 0.421584
# [55]	valid_0's auc: 0.873865	valid_0's binary_logloss: 0.4215
# [56]	valid_0's auc: 0.873815	valid_0's binary_logloss: 0.421509
# [57]	valid_0's auc: 0.873855	valid_0's binary_logloss: 0.421365
# [58]	valid_0's auc: 0.873878	valid_0's binary_logloss: 0.42126
# [59]	valid_0's auc: 0.87388	valid_0's binary_logloss: 0.421183
# [60]	valid_0's auc: 0.873887	valid_0's binary_logloss: 0.421147
# [61]	valid_0's auc: 0.873839	valid_0's binary_logloss: 0.421131
# [62]	valid_0's auc: 0.873841	valid_0's binary_logloss: 0.421114
# [63]	valid_0's auc: 0.873843	valid_0's binary_logloss: 0.421069
# [64]	valid_0's auc: 0.873776	valid_0's binary_logloss: 0.421045
# [65]	valid_0's auc: 0.873736	valid_0's binary_logloss: 0.421062
# [66]	valid_0's auc: 0.873702	valid_0's binary_logloss: 0.420998
# [67]	valid_0's auc: 0.873709	valid_0's binary_logloss: 0.42098
# [68]	valid_0's auc: 0.873733	valid_0's binary_logloss: 0.420907
# [69]	valid_0's auc: 0.87372	valid_0's binary_logloss: 0.420883
# [70]	valid_0's auc: 0.873714	valid_0's binary_logloss: 0.420843
# [71]	valid_0's auc: 0.873726	valid_0's binary_logloss: 0.420766
# [72]	valid_0's auc: 0.873675	valid_0's binary_logloss: 0.420777
# [73]	valid_0's auc: 0.873626	valid_0's binary_logloss: 0.420808
# [74]	valid_0's auc: 0.873605	valid_0's binary_logloss: 0.420802
# [75]	valid_0's auc: 0.873539	valid_0's binary_logloss: 0.420818
# [76]	valid_0's auc: 0.873517	valid_0's binary_logloss: 0.420831
# [77]	valid_0's auc: 0.8735	valid_0's binary_logloss: 0.42081
# [78]	valid_0's auc: 0.873519	valid_0's binary_logloss: 0.420777
# [79]	valid_0's auc: 0.873485	valid_0's binary_logloss: 0.420775
# [80]	valid_0's auc: 0.873501	valid_0's binary_logloss: 0.42072
# [81]	valid_0's auc: 0.873549	valid_0's binary_logloss: 0.420693
# [82]	valid_0's auc: 0.87354	valid_0's binary_logloss: 0.420687
# [83]	valid_0's auc: 0.873519	valid_0's binary_logloss: 0.420689
# [84]	valid_0's auc: 0.873501	valid_0's binary_logloss: 0.420686
# [85]	valid_0's auc: 0.873493	valid_0's binary_logloss: 0.420682
# [86]	valid_0's auc: 0.873537	valid_0's binary_logloss: 0.420658
# [87]	valid_0's auc: 0.873507	valid_0's binary_logloss: 0.420649
# [88]	valid_0's auc: 0.873484	valid_0's binary_logloss: 0.420648
# [89]	valid_0's auc: 0.87348	valid_0's binary_logloss: 0.420632
# [90]	valid_0's auc: 0.873474	valid_0's binary_logloss: 0.420623
# [91]	valid_0's auc: 0.873464	valid_0's binary_logloss: 0.420598
# [92]	valid_0's auc: 0.873485	valid_0's binary_logloss: 0.420574
# [93]	valid_0's auc: 0.87344	valid_0's binary_logloss: 0.42058
# [94]	valid_0's auc: 0.873444	valid_0's binary_logloss: 0.420559
# [95]	valid_0's auc: 0.873438	valid_0's binary_logloss: 0.420515
# [96]	valid_0's auc: 0.87343	valid_0's binary_logloss: 0.420513
# [97]	valid_0's auc: 0.873429	valid_0's binary_logloss: 0.420459
# [98]	valid_0's auc: 0.87339	valid_0's binary_logloss: 0.420482
# [99]	valid_0's auc: 0.873411	valid_0's binary_logloss: 0.420446
# [100]	valid_0's auc: 0.87337	valid_0's binary_logloss: 0.420451
# ROC_AUC
# ***************************
# 0.8740889321007188
# None
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['AGE_BIN', 'CHANNEL_CODE', 'CREDIT_PRODUCT', 'GENDER', 'IS_ACTIVE', 'OCCUPATION', 'REGION_CODE', 'VINTAGE_BIN']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [1]	valid_0's auc: 0.866832	valid_0's binary_logloss: 0.652526
# [2]	valid_0's auc: 0.867813	valid_0's binary_logloss: 0.619449
# [3]	valid_0's auc: 0.869735	valid_0's binary_logloss: 0.590765
# [4]	valid_0's auc: 0.87055	valid_0's binary_logloss: 0.566908
# [5]	valid_0's auc: 0.870725	valid_0's binary_logloss: 0.547056
# [6]	valid_0's auc: 0.870846	valid_0's binary_logloss: 0.52999
# [7]	valid_0's auc: 0.871185	valid_0's binary_logloss: 0.515552
# [8]	valid_0's auc: 0.871232	valid_0's binary_logloss: 0.503235
# [9]	valid_0's auc: 0.871453	valid_0's binary_logloss: 0.49248
# [10]	valid_0's auc: 0.871616	valid_0's binary_logloss: 0.483732
# [11]	valid_0's auc: 0.87167	valid_0's binary_logloss: 0.475776
# [12]	valid_0's auc: 0.871592	valid_0's binary_logloss: 0.469381
# [13]	valid_0's auc: 0.871963	valid_0's binary_logloss: 0.466136
# [14]	valid_0's auc: 0.871856	valid_0's binary_logloss: 0.460999
# [15]	valid_0's auc: 0.871904	valid_0's binary_logloss: 0.456208
# [16]	valid_0's auc: 0.872157	valid_0's binary_logloss: 0.451833
# [17]	valid_0's auc: 0.872368	valid_0's binary_logloss: 0.448069
# [18]	valid_0's auc: 0.872546	valid_0's binary_logloss: 0.444729
# [19]	valid_0's auc: 0.872481	valid_0's binary_logloss: 0.442313
# [20]	valid_0's auc: 0.872573	valid_0's binary_logloss: 0.439806
# [21]	valid_0's auc: 0.8727	valid_0's binary_logloss: 0.437584
# [22]	valid_0's auc: 0.872728	valid_0's binary_logloss: 0.435701
# [23]	valid_0's auc: 0.872753	valid_0's binary_logloss: 0.434195
# [24]	valid_0's auc: 0.872758	valid_0's binary_logloss: 0.433076
# [25]	valid_0's auc: 0.872823	valid_0's binary_logloss: 0.431819
# [26]	valid_0's auc: 0.872804	valid_0's binary_logloss: 0.431147
# [27]	valid_0's auc: 0.872936	valid_0's binary_logloss: 0.430142
# [28]	valid_0's auc: 0.872953	valid_0's binary_logloss: 0.42957
# [29]	valid_0's auc: 0.872901	valid_0's binary_logloss: 0.428764
# [30]	valid_0's auc: 0.872869	valid_0's binary_logloss: 0.428582
# [31]	valid_0's auc: 0.872834	valid_0's binary_logloss: 0.427865
# [32]	valid_0's auc: 0.872933	valid_0's binary_logloss: 0.427145
# [33]	valid_0's auc: 0.872927	valid_0's binary_logloss: 0.426648
# [34]	valid_0's auc: 0.873014	valid_0's binary_logloss: 0.426328
# [35]	valid_0's auc: 0.873009	valid_0's binary_logloss: 0.426061
# [36]	valid_0's auc: 0.87308	valid_0's binary_logloss: 0.42558
# [37]	valid_0's auc: 0.873119	valid_0's binary_logloss: 0.425134
# [38]	valid_0's auc: 0.873178	valid_0's binary_logloss: 0.42491
# [39]	valid_0's auc: 0.873153	valid_0's binary_logloss: 0.424619
# [40]	valid_0's auc: 0.873186	valid_0's binary_logloss: 0.424358
# [41]	valid_0's auc: 0.873224	valid_0's binary_logloss: 0.424112
# [42]	valid_0's auc: 0.873182	valid_0's binary_logloss: 0.423968
# [43]	valid_0's auc: 0.873213	valid_0's binary_logloss: 0.423838
# [44]	valid_0's auc: 0.873216	valid_0's binary_logloss: 0.42363
# [45]	valid_0's auc: 0.873219	valid_0's binary_logloss: 0.42345
# [46]	valid_0's auc: 0.873221	valid_0's binary_logloss: 0.423369
# [47]	valid_0's auc: 0.873205	valid_0's binary_logloss: 0.423265
# [48]	valid_0's auc: 0.873207	valid_0's binary_logloss: 0.423184
# [49]	valid_0's auc: 0.873214	valid_0's binary_logloss: 0.423086
# [50]	valid_0's auc: 0.87322	valid_0's binary_logloss: 0.423002
# [51]	valid_0's auc: 0.873224	valid_0's binary_logloss: 0.422899
# [52]	valid_0's auc: 0.873206	valid_0's binary_logloss: 0.422829
# [53]	valid_0's auc: 0.873139	valid_0's binary_logloss: 0.422816
# [54]	valid_0's auc: 0.873147	valid_0's binary_logloss: 0.422758
# [55]	valid_0's auc: 0.873114	valid_0's binary_logloss: 0.422741
# [56]	valid_0's auc: 0.873172	valid_0's binary_logloss: 0.422697
# [57]	valid_0's auc: 0.873188	valid_0's binary_logloss: 0.42261
# [58]	valid_0's auc: 0.873164	valid_0's binary_logloss: 0.422518
# [59]	valid_0's auc: 0.873177	valid_0's binary_logloss: 0.422501
# [60]	valid_0's auc: 0.873159	valid_0's binary_logloss: 0.422449
# [61]	valid_0's auc: 0.873125	valid_0's binary_logloss: 0.422444
# [62]	valid_0's auc: 0.873122	valid_0's binary_logloss: 0.422441
# [63]	valid_0's auc: 0.873141	valid_0's binary_logloss: 0.422415
# [64]	valid_0's auc: 0.873119	valid_0's binary_logloss: 0.422376
# [65]	valid_0's auc: 0.873151	valid_0's binary_logloss: 0.422361
# [66]	valid_0's auc: 0.873219	valid_0's binary_logloss: 0.422303
# [67]	valid_0's auc: 0.873231	valid_0's binary_logloss: 0.422263
# [68]	valid_0's auc: 0.873215	valid_0's binary_logloss: 0.422266
# [69]	valid_0's auc: 0.873201	valid_0's binary_logloss: 0.42222
# [70]	valid_0's auc: 0.873219	valid_0's binary_logloss: 0.422207
# [71]	valid_0's auc: 0.873206	valid_0's binary_logloss: 0.422139
# [72]	valid_0's auc: 0.873234	valid_0's binary_logloss: 0.422094
# [73]	valid_0's auc: 0.873217	valid_0's binary_logloss: 0.422056
# [74]	valid_0's auc: 0.873218	valid_0's binary_logloss: 0.422026
# [75]	valid_0's auc: 0.873231	valid_0's binary_logloss: 0.422003
# [76]	valid_0's auc: 0.873222	valid_0's binary_logloss: 0.42196
# [77]	valid_0's auc: 0.873224	valid_0's binary_logloss: 0.421941
# [78]	valid_0's auc: 0.873207	valid_0's binary_logloss: 0.421924
# [79]	valid_0's auc: 0.873251	valid_0's binary_logloss: 0.421867
# [80]	valid_0's auc: 0.873191	valid_0's binary_logloss: 0.421863
# [81]	valid_0's auc: 0.873186	valid_0's binary_logloss: 0.421812
# [82]	valid_0's auc: 0.873183	valid_0's binary_logloss: 0.421795
# [83]	valid_0's auc: 0.873175	valid_0's binary_logloss: 0.421786
# [84]	valid_0's auc: 0.873211	valid_0's binary_logloss: 0.421734
# [85]	valid_0's auc: 0.873188	valid_0's binary_logloss: 0.421702
# [86]	valid_0's auc: 0.87315	valid_0's binary_logloss: 0.421725
# [87]	valid_0's auc: 0.873122	valid_0's binary_logloss: 0.421737
# [88]	valid_0's auc: 0.873123	valid_0's binary_logloss: 0.421731
# [89]	valid_0's auc: 0.873124	valid_0's binary_logloss: 0.421731
# [90]	valid_0's auc: 0.873145	valid_0's binary_logloss: 0.421712
# [91]	valid_0's auc: 0.873134	valid_0's binary_logloss: 0.42169
# [92]	valid_0's auc: 0.873145	valid_0's binary_logloss: 0.421683
# [93]	valid_0's auc: 0.873141	valid_0's binary_logloss: 0.421639
# [94]	valid_0's auc: 0.87311	valid_0's binary_logloss: 0.421666
# [95]	valid_0's auc: 0.873073	valid_0's binary_logloss: 0.421656
# [96]	valid_0's auc: 0.873066	valid_0's binary_logloss: 0.421663
# [97]	valid_0's auc: 0.873063	valid_0's binary_logloss: 0.421646
# [98]	valid_0's auc: 0.873019	valid_0's binary_logloss: 0.421653
# [99]	valid_0's auc: 0.87302	valid_0's binary_logloss: 0.421639
# [100]	valid_0's auc: 0.872998	valid_0's binary_logloss: 0.421625
# ROC_AUC
# ***************************
# 0.873571320930914
# None
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['AGE_BIN', 'CHANNEL_CODE', 'CREDIT_PRODUCT', 'GENDER', 'IS_ACTIVE', 'OCCUPATION', 'REGION_CODE', 'VINTAGE_BIN']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [1]	valid_0's auc: 0.865596	valid_0's binary_logloss: 0.652851
# [2]	valid_0's auc: 0.867336	valid_0's binary_logloss: 0.62011
# [3]	valid_0's auc: 0.8697	valid_0's binary_logloss: 0.59175
# [4]	valid_0's auc: 0.870279	valid_0's binary_logloss: 0.568115
# [5]	valid_0's auc: 0.870539	valid_0's binary_logloss: 0.54862
# [6]	valid_0's auc: 0.870913	valid_0's binary_logloss: 0.531671
# [7]	valid_0's auc: 0.870894	valid_0's binary_logloss: 0.517373
# [8]	valid_0's auc: 0.871553	valid_0's binary_logloss: 0.505111
# [9]	valid_0's auc: 0.871588	valid_0's binary_logloss: 0.494565
# [10]	valid_0's auc: 0.871594	valid_0's binary_logloss: 0.485956
# [11]	valid_0's auc: 0.871671	valid_0's binary_logloss: 0.478217
# [12]	valid_0's auc: 0.871441	valid_0's binary_logloss: 0.472011
# [13]	valid_0's auc: 0.871989	valid_0's binary_logloss: 0.468732
# [14]	valid_0's auc: 0.871867	valid_0's binary_logloss: 0.463751
# [15]	valid_0's auc: 0.871913	valid_0's binary_logloss: 0.459102
# [16]	valid_0's auc: 0.872077	valid_0's binary_logloss: 0.454871
# [17]	valid_0's auc: 0.872257	valid_0's binary_logloss: 0.45114
# [18]	valid_0's auc: 0.872373	valid_0's binary_logloss: 0.447938
# [19]	valid_0's auc: 0.872361	valid_0's binary_logloss: 0.44558
# [20]	valid_0's auc: 0.872483	valid_0's binary_logloss: 0.443063
# [21]	valid_0's auc: 0.872642	valid_0's binary_logloss: 0.440925
# [22]	valid_0's auc: 0.872686	valid_0's binary_logloss: 0.439126
# [23]	valid_0's auc: 0.872774	valid_0's binary_logloss: 0.437658
# [24]	valid_0's auc: 0.872723	valid_0's binary_logloss: 0.436626
# [25]	valid_0's auc: 0.872746	valid_0's binary_logloss: 0.435362
# [26]	valid_0's auc: 0.87285	valid_0's binary_logloss: 0.434626
# [27]	valid_0's auc: 0.872937	valid_0's binary_logloss: 0.433565
# [28]	valid_0's auc: 0.872959	valid_0's binary_logloss: 0.433016
# [29]	valid_0's auc: 0.873026	valid_0's binary_logloss: 0.43222
# [30]	valid_0's auc: 0.873046	valid_0's binary_logloss: 0.432034
# [31]	valid_0's auc: 0.873105	valid_0's binary_logloss: 0.431321
# [32]	valid_0's auc: 0.873165	valid_0's binary_logloss: 0.430629
# [33]	valid_0's auc: 0.873136	valid_0's binary_logloss: 0.430136
# [34]	valid_0's auc: 0.873245	valid_0's binary_logloss: 0.429776
# [35]	valid_0's auc: 0.873252	valid_0's binary_logloss: 0.429484
# [36]	valid_0's auc: 0.873289	valid_0's binary_logloss: 0.429085
# [37]	valid_0's auc: 0.873311	valid_0's binary_logloss: 0.428747
# [38]	valid_0's auc: 0.87334	valid_0's binary_logloss: 0.428509
# [39]	valid_0's auc: 0.873383	valid_0's binary_logloss: 0.42825
# [40]	valid_0's auc: 0.873482	valid_0's binary_logloss: 0.428033
# [41]	valid_0's auc: 0.873574	valid_0's binary_logloss: 0.427803
# [42]	valid_0's auc: 0.87358	valid_0's binary_logloss: 0.427661
# [43]	valid_0's auc: 0.873615	valid_0's binary_logloss: 0.427532
# [44]	valid_0's auc: 0.873592	valid_0's binary_logloss: 0.427342
# [45]	valid_0's auc: 0.873546	valid_0's binary_logloss: 0.427194
# [46]	valid_0's auc: 0.873565	valid_0's binary_logloss: 0.42708
# [47]	valid_0's auc: 0.873616	valid_0's binary_logloss: 0.426988
# [48]	valid_0's auc: 0.873612	valid_0's binary_logloss: 0.426867
# [49]	valid_0's auc: 0.873661	valid_0's binary_logloss: 0.426746
# [50]	valid_0's auc: 0.873638	valid_0's binary_logloss: 0.426687
# [51]	valid_0's auc: 0.873633	valid_0's binary_logloss: 0.4266
# [52]	valid_0's auc: 0.873682	valid_0's binary_logloss: 0.426524
# [53]	valid_0's auc: 0.873703	valid_0's binary_logloss: 0.426397
# [54]	valid_0's auc: 0.873657	valid_0's binary_logloss: 0.426378
# [55]	valid_0's auc: 0.873646	valid_0's binary_logloss: 0.426348
# [56]	valid_0's auc: 0.873684	valid_0's binary_logloss: 0.426306
# [57]	valid_0's auc: 0.87371	valid_0's binary_logloss: 0.426212
# [58]	valid_0's auc: 0.87372	valid_0's binary_logloss: 0.426134
# [59]	valid_0's auc: 0.873734	valid_0's binary_logloss: 0.426097
# [60]	valid_0's auc: 0.873734	valid_0's binary_logloss: 0.426033
# [61]	valid_0's auc: 0.873701	valid_0's binary_logloss: 0.426005
# [62]	valid_0's auc: 0.873672	valid_0's binary_logloss: 0.426018
# [63]	valid_0's auc: 0.873654	valid_0's binary_logloss: 0.425982
# [64]	valid_0's auc: 0.87366	valid_0's binary_logloss: 0.425968
# [65]	valid_0's auc: 0.873647	valid_0's binary_logloss: 0.425959
# [66]	valid_0's auc: 0.873647	valid_0's binary_logloss: 0.425919
# [67]	valid_0's auc: 0.873592	valid_0's binary_logloss: 0.425917
# [68]	valid_0's auc: 0.873581	valid_0's binary_logloss: 0.425892
# [69]	valid_0's auc: 0.873584	valid_0's binary_logloss: 0.425867
# [70]	valid_0's auc: 0.873567	valid_0's binary_logloss: 0.425869
# [71]	valid_0's auc: 0.873586	valid_0's binary_logloss: 0.425811
# [72]	valid_0's auc: 0.873534	valid_0's binary_logloss: 0.425823
# [73]	valid_0's auc: 0.873588	valid_0's binary_logloss: 0.425758
# [74]	valid_0's auc: 0.873616	valid_0's binary_logloss: 0.425731
# [75]	valid_0's auc: 0.873632	valid_0's binary_logloss: 0.425707
# [76]	valid_0's auc: 0.873619	valid_0's binary_logloss: 0.425722
# [77]	valid_0's auc: 0.873599	valid_0's binary_logloss: 0.425703
# [78]	valid_0's auc: 0.873588	valid_0's binary_logloss: 0.425696
# [79]	valid_0's auc: 0.8736	valid_0's binary_logloss: 0.425655
# [80]	valid_0's auc: 0.873592	valid_0's binary_logloss: 0.425661
# [81]	valid_0's auc: 0.873619	valid_0's binary_logloss: 0.425633
# [82]	valid_0's auc: 0.873614	valid_0's binary_logloss: 0.425588
# [83]	valid_0's auc: 0.873606	valid_0's binary_logloss: 0.425582
# [84]	valid_0's auc: 0.87359	valid_0's binary_logloss: 0.42559
# [85]	valid_0's auc: 0.87359	valid_0's binary_logloss: 0.425576
# [86]	valid_0's auc: 0.873567	valid_0's binary_logloss: 0.425571
# [87]	valid_0's auc: 0.873583	valid_0's binary_logloss: 0.42554
# [88]	valid_0's auc: 0.873623	valid_0's binary_logloss: 0.425502
# [89]	valid_0's auc: 0.873582	valid_0's binary_logloss: 0.42552
# [90]	valid_0's auc: 0.873576	valid_0's binary_logloss: 0.425521
# [91]	valid_0's auc: 0.873568	valid_0's binary_logloss: 0.42551
# [92]	valid_0's auc: 0.873581	valid_0's binary_logloss: 0.425463
# [93]	valid_0's auc: 0.873568	valid_0's binary_logloss: 0.425449
# [94]	valid_0's auc: 0.873587	valid_0's binary_logloss: 0.425427
# [95]	valid_0's auc: 0.873586	valid_0's binary_logloss: 0.425403
# [96]	valid_0's auc: 0.873594	valid_0's binary_logloss: 0.425404
# [97]	valid_0's auc: 0.873603	valid_0's binary_logloss: 0.425381
# [98]	valid_0's auc: 0.873531	valid_0's binary_logloss: 0.425384
# [99]	valid_0's auc: 0.87352	valid_0's binary_logloss: 0.425383
# [100]	valid_0's auc: 0.873519	valid_0's binary_logloss: 0.425366
# ROC_AUC
# ***************************
# 0.8740781198270081
# None
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['AGE_BIN', 'CHANNEL_CODE', 'CREDIT_PRODUCT', 'GENDER', 'IS_ACTIVE', 'OCCUPATION', 'REGION_CODE', 'VINTAGE_BIN']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [1]	valid_0's auc: 0.86646	valid_0's binary_logloss: 0.652583
# [2]	valid_0's auc: 0.867969	valid_0's binary_logloss: 0.619694
# [3]	valid_0's auc: 0.870693	valid_0's binary_logloss: 0.59104
# [4]	valid_0's auc: 0.871492	valid_0's binary_logloss: 0.567175
# [5]	valid_0's auc: 0.871516	valid_0's binary_logloss: 0.547345
# [6]	valid_0's auc: 0.871859	valid_0's binary_logloss: 0.530211
# [7]	valid_0's auc: 0.872259	valid_0's binary_logloss: 0.51559
# [8]	valid_0's auc: 0.872489	valid_0's binary_logloss: 0.503244
# [9]	valid_0's auc: 0.872925	valid_0's binary_logloss: 0.492367
# [10]	valid_0's auc: 0.872881	valid_0's binary_logloss: 0.483576
# [11]	valid_0's auc: 0.873033	valid_0's binary_logloss: 0.475661
# [12]	valid_0's auc: 0.872887	valid_0's binary_logloss: 0.469255
# [13]	valid_0's auc: 0.873289	valid_0's binary_logloss: 0.46588
# [14]	valid_0's auc: 0.873089	valid_0's binary_logloss: 0.46079
# [15]	valid_0's auc: 0.873173	valid_0's binary_logloss: 0.456033
# [16]	valid_0's auc: 0.87337	valid_0's binary_logloss: 0.45165
# [17]	valid_0's auc: 0.873643	valid_0's binary_logloss: 0.447756
# [18]	valid_0's auc: 0.873921	valid_0's binary_logloss: 0.444325
# [19]	valid_0's auc: 0.873837	valid_0's binary_logloss: 0.441918
# [20]	valid_0's auc: 0.874105	valid_0's binary_logloss: 0.439253
# [21]	valid_0's auc: 0.874273	valid_0's binary_logloss: 0.436985
# [22]	valid_0's auc: 0.874384	valid_0's binary_logloss: 0.435054
# [23]	valid_0's auc: 0.874562	valid_0's binary_logloss: 0.433266
# [24]	valid_0's auc: 0.874477	valid_0's binary_logloss: 0.432155
# [25]	valid_0's auc: 0.874612	valid_0's binary_logloss: 0.430844
# [26]	valid_0's auc: 0.874681	valid_0's binary_logloss: 0.430109
# [27]	valid_0's auc: 0.874804	valid_0's binary_logloss: 0.429068
# [28]	valid_0's auc: 0.874908	valid_0's binary_logloss: 0.428453
# [29]	valid_0's auc: 0.874916	valid_0's binary_logloss: 0.427632
# [30]	valid_0's auc: 0.874874	valid_0's binary_logloss: 0.427432
# [31]	valid_0's auc: 0.874904	valid_0's binary_logloss: 0.426737
# [32]	valid_0's auc: 0.875033	valid_0's binary_logloss: 0.426015
# [33]	valid_0's auc: 0.875013	valid_0's binary_logloss: 0.425515
# [34]	valid_0's auc: 0.875156	valid_0's binary_logloss: 0.425131
# [35]	valid_0's auc: 0.875113	valid_0's binary_logloss: 0.424869
# [36]	valid_0's auc: 0.875179	valid_0's binary_logloss: 0.424436
# [37]	valid_0's auc: 0.875219	valid_0's binary_logloss: 0.423985
# [38]	valid_0's auc: 0.875287	valid_0's binary_logloss: 0.423701
# [39]	valid_0's auc: 0.87529	valid_0's binary_logloss: 0.423339
# [40]	valid_0's auc: 0.875388	valid_0's binary_logloss: 0.423077
# [41]	valid_0's auc: 0.875386	valid_0's binary_logloss: 0.422887
# [42]	valid_0's auc: 0.875411	valid_0's binary_logloss: 0.422724
# [43]	valid_0's auc: 0.875455	valid_0's binary_logloss: 0.42257
# [44]	valid_0's auc: 0.875459	valid_0's binary_logloss: 0.422325
# [45]	valid_0's auc: 0.875471	valid_0's binary_logloss: 0.422145
# [46]	valid_0's auc: 0.875494	valid_0's binary_logloss: 0.421993
# [47]	valid_0's auc: 0.875538	valid_0's binary_logloss: 0.421814
# [48]	valid_0's auc: 0.8755	valid_0's binary_logloss: 0.421645
# [49]	valid_0's auc: 0.875436	valid_0's binary_logloss: 0.42159
# [50]	valid_0's auc: 0.875408	valid_0's binary_logloss: 0.421521
# [51]	valid_0's auc: 0.875345	valid_0's binary_logloss: 0.421478
# [52]	valid_0's auc: 0.875393	valid_0's binary_logloss: 0.421388
# [53]	valid_0's auc: 0.87541	valid_0's binary_logloss: 0.421256
# [54]	valid_0's auc: 0.875418	valid_0's binary_logloss: 0.42117
# [55]	valid_0's auc: 0.875451	valid_0's binary_logloss: 0.421106
# [56]	valid_0's auc: 0.875414	valid_0's binary_logloss: 0.421103
# [57]	valid_0's auc: 0.875442	valid_0's binary_logloss: 0.420966
# [58]	valid_0's auc: 0.875441	valid_0's binary_logloss: 0.420894
# [59]	valid_0's auc: 0.875396	valid_0's binary_logloss: 0.420926
# [60]	valid_0's auc: 0.875415	valid_0's binary_logloss: 0.420834
# [61]	valid_0's auc: 0.875429	valid_0's binary_logloss: 0.420798
# [62]	valid_0's auc: 0.875419	valid_0's binary_logloss: 0.420714
# [63]	valid_0's auc: 0.875353	valid_0's binary_logloss: 0.42073
# [64]	valid_0's auc: 0.875368	valid_0's binary_logloss: 0.420704
# [65]	valid_0's auc: 0.875366	valid_0's binary_logloss: 0.420689
# [66]	valid_0's auc: 0.875382	valid_0's binary_logloss: 0.420605
# [67]	valid_0's auc: 0.875367	valid_0's binary_logloss: 0.420601
# [68]	valid_0's auc: 0.875381	valid_0's binary_logloss: 0.420548
# [69]	valid_0's auc: 0.87538	valid_0's binary_logloss: 0.420525
# [70]	valid_0's auc: 0.875387	valid_0's binary_logloss: 0.420466
# [71]	valid_0's auc: 0.875397	valid_0's binary_logloss: 0.420443
# [72]	valid_0's auc: 0.875406	valid_0's binary_logloss: 0.420411
# [73]	valid_0's auc: 0.875423	valid_0's binary_logloss: 0.420377
# [74]	valid_0's auc: 0.87545	valid_0's binary_logloss: 0.420338
# [75]	valid_0's auc: 0.875463	valid_0's binary_logloss: 0.420315
# [76]	valid_0's auc: 0.87546	valid_0's binary_logloss: 0.420294
# [77]	valid_0's auc: 0.875447	valid_0's binary_logloss: 0.420253
# [78]	valid_0's auc: 0.875419	valid_0's binary_logloss: 0.420277
# [79]	valid_0's auc: 0.875396	valid_0's binary_logloss: 0.420256
# [80]	valid_0's auc: 0.875401	valid_0's binary_logloss: 0.420246
# [81]	valid_0's auc: 0.875404	valid_0's binary_logloss: 0.420202
# [82]	valid_0's auc: 0.87539	valid_0's binary_logloss: 0.420188
# [83]	valid_0's auc: 0.875381	valid_0's binary_logloss: 0.420193
# [84]	valid_0's auc: 0.875354	valid_0's binary_logloss: 0.420169
# [85]	valid_0's auc: 0.875356	valid_0's binary_logloss: 0.420137
# [86]	valid_0's auc: 0.875349	valid_0's binary_logloss: 0.420076
# [87]	valid_0's auc: 0.875316	valid_0's binary_logloss: 0.420058
# [88]	valid_0's auc: 0.875363	valid_0's binary_logloss: 0.419993
# [89]	valid_0's auc: 0.875353	valid_0's binary_logloss: 0.419984
# [90]	valid_0's auc: 0.875337	valid_0's binary_logloss: 0.419969
# [91]	valid_0's auc: 0.875309	valid_0's binary_logloss: 0.419927
# [92]	valid_0's auc: 0.875338	valid_0's binary_logloss: 0.419888
# [93]	valid_0's auc: 0.875262	valid_0's binary_logloss: 0.419899
# [94]	valid_0's auc: 0.875267	valid_0's binary_logloss: 0.419913
# [95]	valid_0's auc: 0.875239	valid_0's binary_logloss: 0.419921
# [96]	valid_0's auc: 0.875282	valid_0's binary_logloss: 0.419874
# [97]	valid_0's auc: 0.875305	valid_0's binary_logloss: 0.419798
# [98]	valid_0's auc: 0.875292	valid_0's binary_logloss: 0.419808
# [99]	valid_0's auc: 0.875287	valid_0's binary_logloss: 0.419792
# [100]	valid_0's auc: 0.875279	valid_0's binary_logloss: 0.419777
# ROC_AUC
# ***************************
# 0.876036938073112
# None

# %%
train.head()
# Out:
#          ID  GENDER       AGE  ...  VINTAGE_BIN  RATIO_AGE_VINTAGE  RATIO_AC_BAL_AGE
# 0  NNVBBKZB       0  4.290459  ...            1           0.529259          9.569734
# 1  IDD62UNG       0  3.401197  ...            1          -0.064539          9.873008
# 2  HD3DSEMC       0  4.025352  ...            0           0.767255         10.185112
# 3  BF3NC7KV       1  3.526361  ...            0           0.581922          9.535093
# 4  TEASRWXV       0  3.401197  ...            1          -0.095310         10.294163
#
# [5 rows x 23 columns]

# %%
test_pred1 = np.mean(test_pred, axis=0)

test['Is_Lead'] = test_pred1

test[['ID','Is_Lead']].to_csv('baseline.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# HYPERPARAMETER TUNING

# %%
# Objective Function
dtrain = lgb.Dataset(data=x_train, label=y_train, free_raw_data=False)

def lgb_eval(learning_rate,num_leaves, feature_fraction,\
             bagging_fraction, max_depth, \
             lambda_l1, lambda_l2,\
             min_split_gain, min_child_weight,subsample):
        params = {'application':'binary','num_iterations': 1500,
                  'early_stopping_round':150,'class_weight':'balanced',
                  'metric':'auc'} # ,'boost_from_average':False}
        params['learning_rate'] = max(min(learning_rate, 1), 0)          
        params["num_leaves"] = int(round(num_leaves))
        params['feature_fraction'] = max(min(feature_fraction, 1), 0)
        params['bagging_fraction'] = max(min(bagging_fraction, 1), 0)
        params['max_depth'] = int(round(max_depth))
        params['lambda_l1'] = max(lambda_l1, 0)
        params['lambda_l2'] = max(lambda_l2, 0)
        params['min_split_gain'] = min_split_gain
        params['min_child_weight'] = min_child_weight,
        params['subsample'] = max(min(subsample, 1), 0)
        cv_result = lgb.cv(params, dtrain, nfold=5, seed=11,
                           stratified=True,categorical_feature= CATEGORICAL_COL,
                            verbose_eval =None)
        return max(cv_result['auc-mean'])

pbs = {'learning_rate': (0.01, 1.0),
    'num_leaves': (200, 400),
        'feature_fraction': (0.1, 0.9),
        'bagging_fraction': (0.8, 1),
        'max_depth': (11, 29),
        'lambda_l1': (0, 2),
        'lambda_l2': (0, 3),
        'min_split_gain': (0.001, 0.1),
        'min_child_weight': (1, 10),
       'subsample': (0.01, 1.0)
      }


from bayes_opt import BayesianOptimization
optimizer = BayesianOptimization(lgb_eval, pbs, random_state=0)
optimizer.maximize(init_points=5, n_iter=30)

# %%
optimizer.max['params']
# Out:
# {'bagging_fraction': 0.8311485666872785,
#  'feature_fraction': 0.8379604070873502,
#  'lambda_l1': 1.9965195846273445,
#  'lambda_l2': 2.3749163983987684,
#  'learning_rate': 0.010966236844973847,
#  'max_depth': 12.421995123923814,
#  'min_child_weight': 4.3310407596078795,
#  'min_split_gain': 0.04390640960548089,
#  'num_leaves': 200.9699390530843,
#  'subsample': 0.25565702591322664}

# %% [markdown]
# LGBM performed better as a baseline model and applying kfold improved the model by 1 % no further transformation and processing is done

# %% [markdown]
# FEATURE ENGINEERING

# %%
train['IS_TRAIN'] = 1
test['IS_TRAIN'] = 0

df = pd.concat([train, test])

# %%
def get_kurtosis(arr):
  kurt = kurtosis(arr)
  return kurt

def get_iqr(arr):
  iqr_val = iqr(arr)
  return iqr_val 

def get_range(arr):
  range_val = np.ptp(arr)
  return range_val

# %%
def get_agg_cols(train, col):
  # for i in range(len(CATEGORICAL_COL),1,-1):
    train[f'{col}_MEAN_{i}'] = train.groupby(['REGION_CODE'])[col].transform('mean')
    train[f'{col}_STD_{i}'] = train.groupby(['REGION_CODE'])[col].transform('std')
    train[f'{col}_SKEW_{i}'] = train.groupby(['REGION_CODE'])[col].transform('skew')
    train[f'{col}_KURTOSIS_{i}'] = train.groupby(['REGION_CODE'])[col].transform(get_kurtosis)
    train[f'{col}_IQR_{i}'] = train.groupby(['REGION_CODE'])[col].transform(get_iqr)
    train[f'{col}_RANGE_{i}'] = train.groupby(['REGION_CODE'])[col].transform(get_range)
    # train[f'{col}_MEAN_{i+1}'] = train.groupby(['REGION_CODE','OCCUPATION'])[col].transform('mean')
    # train[f'{col}_STD_{i+1}'] = train.groupby(['REGION_CODE','OCCUPATION'])[col].transform('std')
    # train[f'{col}_SKEW_{i+1}'] = train.groupby(['REGION_CODE','OCCUPATION'])[col].transform('skew')
    # train[f'{col}_KURTOSIS_{i+1}'] = train.groupby(['REGION_CODE','OCCUPATION'])[col].transform(get_kurtosis)
    # train[f'{col}_IQR_{i+1}'] = train.groupby(['REGION_CODE','OCCUPATION'])[col].transform(get_iqr)
    # train[f'{col}_RANGE_{i+1}'] = train.groupby(['REGION_CODE','OCCUPATION'])[col].transform(get_range)
    return train

# %%
# Aggregate values based on categorical column on age, vintage and account balance

df = get_agg_cols(df,'AGE')
# df = get_agg_cols(df,'VINTAGE')
df = get_agg_cols(df,'AVG_ACCOUNT_BALANCE')

# %%
def binning_col(train, col):
  # no of bins and edges 
  hist, bin_edg = np.histogram(train[col].values,bins='sturges')
  Bin = KBinsDiscretizer(n_bins=6, encode='ordinal', strategy='kmeans')
  train[f'{col}_BIN'] = Bin.fit_transform(train[col].values.reshape(-1, 1))
  return train

df = binning_col(df,'AGE')
df = binning_col(df,'VINTAGE')

CATEGORICAL_COL += ['AGE_BIN','VINTAGE_BIN']

# %%
# concatenating categorical columns
CONCAT_CATEGORICAL_COL = []

for ix, i in enumerate(CATEGORICAL_COL[:-2]):
  if i == 'REGION_CODE': continue
  for j in CATEGORICAL_COL[ix:-2]:
    if i==j: continue
    col = str(i) + '_' + str(j)
    df[col] = df[i] + '_' + df[j]
    CONCAT_CATEGORICAL_COL.append(col)


CATEGORICAL_COL += CONCAT_CATEGORICAL_COL

# %%
# ratio features 

df['RATIO_AGE_VINTAGE'] = np.log(df['AGE']/df['VINTAGE'])
# df['RATIO_AC_BAL_VINTAGE'] = np.log(df['AVG_ACCOUNT_BALANCE']/df['VINTAGE'])
df['RATIO_AC_BAL_AGE'] = np.log(df['AVG_ACCOUNT_BALANCE']/df['AGE'])
df['AVG_ACCOUNT_BALANCE'] = np.log(df['AVG_ACCOUNT_BALANCE'])
df['AGE'] = np.log(df['AGE'])
df['VINTAGE'] = np.log(df['VINTAGE'])

# %%
def target_encoding(train, valid, test):
  for c in CATEGORICAL_COL:
    val_dict = train.groupby([c]).agg({'IS_LEAD':'mean'}).to_dict()['IS_LEAD']
    train[f'{c}_TARGET_ENCODING'] = train[c].map(val_dict)
    valid[f'{c}_TARGET_ENCODING'] = valid[c].map(val_dict)
    test[f'{c}_TARGET_ENCODING'] = test[c].map(val_dict)
  return train, valid, test

# %%
# CLUSTER FEATURES

df = pd.get_dummies(df, columns=CATEGORICAL_COL)

df['AGE'] = np.log(df['AGE'])
df['VINTAGE'] = np.log(df['VINTAGE'])

kmeanModel = KMeans(n_clusters=5)
cluster_label = kmeanModel.fit_predict(df.drop(['IS_LEAD','KFOLD','ID'], axis=1))

df['CLUSTER'] = cluster_label

df = pd.get_dummies(df, columns=['CLUSTER'])

# %%
# ENCODING the categorical columns

train = df[df['IS_TRAIN']==1]
test = df[df['IS_TRAIN']==0]

encoder = LabelEncoder()

for c in CATEGORICAL_COL:
    train[c] = encoder.fit_transform(train[c])
    test[c] = encoder.transform(test[c])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# FIND OPTIMAL MODEL

# %%
x_train,  x_val, y_train, y_val = split(train)

# %% [markdown]
# LGBM

# %%
lightgbm_params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'class_weight':'balanced'
}

d_train = lgb.Dataset(x_train, label=y_train)
lg_cv = lgb.cv(lightgbm_params, d_train,nfold=5, 
               verbose_eval=20, early_stopping_rounds=40, shuffle=False)

# %%
print('Best CV score:', np.mean(lg_cv['auc-mean']))
# Out:
# Best CV score: 0.8724213313135205

# %% [markdown]
# CATBOOST

# %%
params = {"iterations": 100,
          "loss_function": "Logloss",
          'custom_metric':'AUC',
          'class_weights':[1,3],
          "verbose": False}

cv_data = Pool(data=x_train,
                  label=y_train)

scores = cv(cv_data,
            params,
            fold_count=5, shuffle=False)

# %%
scores['test-AUC-mean'].max()
# Out:
# 0.8715988266015042

# %% [markdown]
# XGBOOST and ADABOOST

# %%
xgtrain = xgb.DMatrix(x_train, y_train )
model_xg=xgb.XGBClassifier(random_state=0, scale_pos_weight=3)
xgb_param = model_xg.get_xgb_params()

xg_cv = xgb.cv(xgb_param, xgtrain, nfold=5, metrics='auc', seed=0)

# %%
xg_cv
# Out:
#    train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 0        0.870913       0.000635       0.869575      0.002480
# 1        0.871968       0.000496       0.870376      0.002349
# 2        0.872788       0.000564       0.870754      0.002223
# 3        0.873751       0.000566       0.871609      0.002306
# 4        0.874107       0.000616       0.871781      0.002287
# 5        0.874642       0.000716       0.872052      0.002163
# 6        0.875122       0.000639       0.872295      0.002190
# 7        0.875581       0.000504       0.872522      0.002298
# 8        0.876051       0.000604       0.872745      0.002211
# 9        0.876688       0.000558       0.872974      0.002238

# %%
rf_model = RandomForestClassifier(class_weight='balanced')
rf = cross_validate(rf_model, x_train, y_train, cv=5, scoring='roc_auc', n_jobs=-1)

# %%
np.mean(rf['test_score'])
# Out:
# 0.8525026413479596

# %%
test_pred = []
for i in range(5):
  to_train = train[train['KFOLD']!=i].drop(['ID','IS_TRAIN','KFOLD'], axis=1)
  to_val = train[train['KFOLD']==i].drop(['ID','IS_TRAIN','KFOLD'], axis=1)
  # to_train, to_val, test = target_encoding(to_train, to_val, test)
  x_train = to_train.drop(['IS_LEAD'], axis=1)
  y_train = to_train['IS_LEAD']
  x_val = to_val.drop(['IS_LEAD'], axis=1)
  y_val = to_val['IS_LEAD']
  test_temp = test[x_train.columns]

  # # standardise values
  # scaler = StandardScaler() 

  # SCALE_COL = list(set(x_train.columns) - set(CATEGORICAL_COL) - \
  #                   set([x for x in x_train.columns if '_ENCODING' in x]) - \
  #                   set(['AGE','VINTAGE']))
  
  # x_train[SCALE_COL] = scaler.fit_transform(x_train[SCALE_COL])
  # x_val[SCALE_COL] = scaler.transform(x_val[SCALE_COL])
  # test_temp[SCALE_COL] = scaler.transform(test_temp[SCALE_COL])

  model_lg = lgb.LGBMClassifier(random_state=0, n_estimators=200, 
                class_weight='balanced')
  
  model_xg = xgb.XGBClassifier(n_estimators=100,random_state=0,
                               eval_metric='auc', learning_rate=0.1)
  
  model_cat = CatBoostClassifier(class_weights=[1,3], iterations = 200,
                                 eval_metric='AUC', silent=True)

  
  model_lg.fit(x_train, y_train, #categorical_feature=CATEGORICAL_COL,\
            eval_metric='auc', eval_set=[(x_val,y_val)])
  
  model_xg.fit(x_train, y_train, #categorical_feature=CATEGORICAL_COL,\
            eval_metric='auc', eval_set=[(x_val,y_val)])
  
  model_cat.fit(x_train, y_train, #categorical_feature=CATEGORICAL_COL,\
             eval_set=[(x_val,y_val)])
  
  val_pred1 = model_lg.predict_proba(x_val)[:,1]
  val_pred2 = model_xg.predict_proba(x_val)[:,1]
  val_pred3 = model_cat.predict_proba(x_val)[:,1]


  val_pred = 0.5*val_pred1 + 0.3*val_pred2 + 0.2*val_pred3 
  print(evaluate_model(y_val, val_pred))

  pred1 = model_lg.predict_proba(test_temp[x_train.columns])[:,1]
  pred2 = model_xg.predict_proba(test_temp[x_train.columns])[:,1]
  pred3 = model_cat.predict_proba(test_temp[x_train.columns])[:,1]
  pred = 0.5*pred1 + 0.3*pred2 + 0.2*pred3
  test_pred.append(pred)
# Out:
# [1]	valid_0's auc: 0.867479	valid_0's binary_logloss: 0.65177
# [2]	valid_0's auc: 0.867922	valid_0's binary_logloss: 0.617768
# [3]	valid_0's auc: 0.868159	valid_0's binary_logloss: 0.589493
# [4]	valid_0's auc: 0.868532	valid_0's binary_logloss: 0.565755
# [5]	valid_0's auc: 0.868775	valid_0's binary_logloss: 0.545615
# [6]	valid_0's auc: 0.868713	valid_0's binary_logloss: 0.528792
# [7]	valid_0's auc: 0.868875	valid_0's binary_logloss: 0.514302
# [8]	valid_0's auc: 0.869109	valid_0's binary_logloss: 0.501864
# [9]	valid_0's auc: 0.86954	valid_0's binary_logloss: 0.491368
# [10]	valid_0's auc: 0.869861	valid_0's binary_logloss: 0.482164
# [11]	valid_0's auc: 0.869912	valid_0's binary_logloss: 0.474408
# [12]	valid_0's auc: 0.869896	valid_0's binary_logloss: 0.467764
# [13]	valid_0's auc: 0.870013	valid_0's binary_logloss: 0.461985
# [14]	valid_0's auc: 0.870185	valid_0's binary_logloss: 0.456955
# [15]	valid_0's auc: 0.870575	valid_0's binary_logloss: 0.452662
# [16]	valid_0's auc: 0.870723	valid_0's binary_logloss: 0.448896
# [17]	valid_0's auc: 0.870784	valid_0's binary_logloss: 0.44567
# [18]	valid_0's auc: 0.870881	valid_0's binary_logloss: 0.442891
# [19]	valid_0's auc: 0.870915	valid_0's binary_logloss: 0.440607
# [20]	valid_0's auc: 0.870924	valid_0's binary_logloss: 0.438482
# [21]	valid_0's auc: 0.871147	valid_0's binary_logloss: 0.43675
# [22]	valid_0's auc: 0.871149	valid_0's binary_logloss: 0.435157
# [23]	valid_0's auc: 0.871248	valid_0's binary_logloss: 0.433782
# [24]	valid_0's auc: 0.871241	valid_0's binary_logloss: 0.432566
# [25]	valid_0's auc: 0.871275	valid_0's binary_logloss: 0.43159
# [26]	valid_0's auc: 0.871531	valid_0's binary_logloss: 0.430638
# [27]	valid_0's auc: 0.87164	valid_0's binary_logloss: 0.429913
# [28]	valid_0's auc: 0.871754	valid_0's binary_logloss: 0.429226
# [29]	valid_0's auc: 0.87187	valid_0's binary_logloss: 0.428699
# [30]	valid_0's auc: 0.871889	valid_0's binary_logloss: 0.428238
# [31]	valid_0's auc: 0.871951	valid_0's binary_logloss: 0.427742
# [32]	valid_0's auc: 0.871964	valid_0's binary_logloss: 0.42741
# [33]	valid_0's auc: 0.872006	valid_0's binary_logloss: 0.426956
# [34]	valid_0's auc: 0.872075	valid_0's binary_logloss: 0.426676
# [35]	valid_0's auc: 0.872198	valid_0's binary_logloss: 0.42649
# [36]	valid_0's auc: 0.872275	valid_0's binary_logloss: 0.426172
# [37]	valid_0's auc: 0.872316	valid_0's binary_logloss: 0.425964
# [38]	valid_0's auc: 0.872345	valid_0's binary_logloss: 0.425779
# [39]	valid_0's auc: 0.872322	valid_0's binary_logloss: 0.42562
# [40]	valid_0's auc: 0.872364	valid_0's binary_logloss: 0.425498
# [41]	valid_0's auc: 0.872347	valid_0's binary_logloss: 0.425358
# [42]	valid_0's auc: 0.872298	valid_0's binary_logloss: 0.42524
# [43]	valid_0's auc: 0.872254	valid_0's binary_logloss: 0.425186
# [44]	valid_0's auc: 0.872277	valid_0's binary_logloss: 0.425074
# [45]	valid_0's auc: 0.872341	valid_0's binary_logloss: 0.424989
# [46]	valid_0's auc: 0.87232	valid_0's binary_logloss: 0.424915
# [47]	valid_0's auc: 0.872356	valid_0's binary_logloss: 0.424864
# [48]	valid_0's auc: 0.872356	valid_0's binary_logloss: 0.424749
# [49]	valid_0's auc: 0.872382	valid_0's binary_logloss: 0.424663
# [50]	valid_0's auc: 0.87234	valid_0's binary_logloss: 0.424586
# [51]	valid_0's auc: 0.872367	valid_0's binary_logloss: 0.424559
# [52]	valid_0's auc: 0.872411	valid_0's binary_logloss: 0.424463
# [53]	valid_0's auc: 0.87241	valid_0's binary_logloss: 0.424417
# [54]	valid_0's auc: 0.872463	valid_0's binary_logloss: 0.424356
# [55]	valid_0's auc: 0.872463	valid_0's binary_logloss: 0.424313
# [56]	valid_0's auc: 0.87254	valid_0's binary_logloss: 0.424177
# [57]	valid_0's auc: 0.872542	valid_0's binary_logloss: 0.424153
# [58]	valid_0's auc: 0.872518	valid_0's binary_logloss: 0.424151
# [59]	valid_0's auc: 0.872512	valid_0's binary_logloss: 0.424124
# [60]	valid_0's auc: 0.872597	valid_0's binary_logloss: 0.424012
# [61]	valid_0's auc: 0.8726	valid_0's binary_logloss: 0.423968
# [62]	valid_0's auc: 0.872634	valid_0's binary_logloss: 0.423954
# [63]	valid_0's auc: 0.872623	valid_0's binary_logloss: 0.42396
# [64]	valid_0's auc: 0.872609	valid_0's binary_logloss: 0.423925
# [65]	valid_0's auc: 0.872568	valid_0's binary_logloss: 0.423911
# [66]	valid_0's auc: 0.872594	valid_0's binary_logloss: 0.423893
# [67]	valid_0's auc: 0.872542	valid_0's binary_logloss: 0.423892
# [68]	valid_0's auc: 0.872543	valid_0's binary_logloss: 0.4239
# [69]	valid_0's auc: 0.872514	valid_0's binary_logloss: 0.423905
# [70]	valid_0's auc: 0.872513	valid_0's binary_logloss: 0.423863
# [71]	valid_0's auc: 0.872531	valid_0's binary_logloss: 0.423841
# [72]	valid_0's auc: 0.872624	valid_0's binary_logloss: 0.423822
# [73]	valid_0's auc: 0.872677	valid_0's binary_logloss: 0.423772
# [74]	valid_0's auc: 0.872709	valid_0's binary_logloss: 0.423754
# [75]	valid_0's auc: 0.87271	valid_0's binary_logloss: 0.423748
# [76]	valid_0's auc: 0.872737	valid_0's binary_logloss: 0.423691
# [77]	valid_0's auc: 0.872755	valid_0's binary_logloss: 0.423667
# [78]	valid_0's auc: 0.872757	valid_0's binary_logloss: 0.42363
# [79]	valid_0's auc: 0.87272	valid_0's binary_logloss: 0.423624
# [80]	valid_0's auc: 0.872771	valid_0's binary_logloss: 0.423595
# [81]	valid_0's auc: 0.87276	valid_0's binary_logloss: 0.423577
# [82]	valid_0's auc: 0.872739	valid_0's binary_logloss: 0.423589
# [83]	valid_0's auc: 0.872745	valid_0's binary_logloss: 0.423572
# [84]	valid_0's auc: 0.872759	valid_0's binary_logloss: 0.423511
# [85]	valid_0's auc: 0.872738	valid_0's binary_logloss: 0.423509
# [86]	valid_0's auc: 0.872723	valid_0's binary_logloss: 0.423482
# [87]	valid_0's auc: 0.872739	valid_0's binary_logloss: 0.423493
# [88]	valid_0's auc: 0.87266	valid_0's binary_logloss: 0.423489
# [89]	valid_0's auc: 0.87274	valid_0's binary_logloss: 0.423452
# [90]	valid_0's auc: 0.872707	valid_0's binary_logloss: 0.423462
# [91]	valid_0's auc: 0.872679	valid_0's binary_logloss: 0.423421
# [92]	valid_0's auc: 0.872639	valid_0's binary_logloss: 0.423429
# [93]	valid_0's auc: 0.872645	valid_0's binary_logloss: 0.423423
# [94]	valid_0's auc: 0.872609	valid_0's binary_logloss: 0.423425
# [95]	valid_0's auc: 0.872627	valid_0's binary_logloss: 0.423397
# [96]	valid_0's auc: 0.872605	valid_0's binary_logloss: 0.423406
# [97]	valid_0's auc: 0.872616	valid_0's binary_logloss: 0.42338
# [98]	valid_0's auc: 0.872626	valid_0's binary_logloss: 0.423349
# [99]	valid_0's auc: 0.872641	valid_0's binary_logloss: 0.423335
# [100]	valid_0's auc: 0.872699	valid_0's binary_logloss: 0.42331
# [101]	valid_0's auc: 0.87268	valid_0's binary_logloss: 0.42331
# [102]	valid_0's auc: 0.872658	valid_0's binary_logloss: 0.42329
# [103]	valid_0's auc: 0.872623	valid_0's binary_logloss: 0.423314
# [104]	valid_0's auc: 0.872669	valid_0's binary_logloss: 0.423304
# [105]	valid_0's auc: 0.872587	valid_0's binary_logloss: 0.423326
# [106]	valid_0's auc: 0.872557	valid_0's binary_logloss: 0.423336
# [107]	valid_0's auc: 0.872543	valid_0's binary_logloss: 0.42332
# [108]	valid_0's auc: 0.872506	valid_0's binary_logloss: 0.423317
# [109]	valid_0's auc: 0.87248	valid_0's binary_logloss: 0.423308
# [110]	valid_0's auc: 0.87248	valid_0's binary_logloss: 0.423295
# [111]	valid_0's auc: 0.872491	valid_0's binary_logloss: 0.423271
# [112]	valid_0's auc: 0.872503	valid_0's binary_logloss: 0.423249
# [113]	valid_0's auc: 0.872501	valid_0's binary_logloss: 0.423253
# [114]	valid_0's auc: 0.872494	valid_0's binary_logloss: 0.423228
# [115]	valid_0's auc: 0.872437	valid_0's binary_logloss: 0.423231
# [116]	valid_0's auc: 0.872459	valid_0's binary_logloss: 0.423175
# [117]	valid_0's auc: 0.872468	valid_0's binary_logloss: 0.423155
# [118]	valid_0's auc: 0.872454	valid_0's binary_logloss: 0.423143
# [119]	valid_0's auc: 0.872462	valid_0's binary_logloss: 0.423122
# [120]	valid_0's auc: 0.872476	valid_0's binary_logloss: 0.423075
# [121]	valid_0's auc: 0.872452	valid_0's binary_logloss: 0.423074
# [122]	valid_0's auc: 0.872394	valid_0's binary_logloss: 0.423071
# [123]	valid_0's auc: 0.872417	valid_0's binary_logloss: 0.423031
# [124]	valid_0's auc: 0.872406	valid_0's binary_logloss: 0.423035
# [125]	valid_0's auc: 0.872371	valid_0's binary_logloss: 0.423043
# [126]	valid_0's auc: 0.872389	valid_0's binary_logloss: 0.423034
# [127]	valid_0's auc: 0.872375	valid_0's binary_logloss: 0.423046
# [128]	valid_0's auc: 0.87241	valid_0's binary_logloss: 0.423019
# [129]	valid_0's auc: 0.872415	valid_0's binary_logloss: 0.423009
# [130]	valid_0's auc: 0.872392	valid_0's binary_logloss: 0.423006
# [131]	valid_0's auc: 0.872415	valid_0's binary_logloss: 0.42296
# [132]	valid_0's auc: 0.872408	valid_0's binary_logloss: 0.422932
# [133]	valid_0's auc: 0.872396	valid_0's binary_logloss: 0.422922
# [134]	valid_0's auc: 0.872368	valid_0's binary_logloss: 0.422912
# [135]	valid_0's auc: 0.872383	valid_0's binary_logloss: 0.422898
# [136]	valid_0's auc: 0.872396	valid_0's binary_logloss: 0.422887
# [137]	valid_0's auc: 0.872367	valid_0's binary_logloss: 0.422889
# [138]	valid_0's auc: 0.872354	valid_0's binary_logloss: 0.422878
# [139]	valid_0's auc: 0.872347	valid_0's binary_logloss: 0.422872
# [140]	valid_0's auc: 0.872312	valid_0's binary_logloss: 0.422892
# [141]	valid_0's auc: 0.87229	valid_0's binary_logloss: 0.42289
# [142]	valid_0's auc: 0.872305	valid_0's binary_logloss: 0.422858
# [143]	valid_0's auc: 0.872303	valid_0's binary_logloss: 0.422832
# [144]	valid_0's auc: 0.872319	valid_0's binary_logloss: 0.422795
# [145]	valid_0's auc: 0.872311	valid_0's binary_logloss: 0.422801
# [146]	valid_0's auc: 0.872324	valid_0's binary_logloss: 0.422783
# [147]	valid_0's auc: 0.872323	valid_0's binary_logloss: 0.422757
# [148]	valid_0's auc: 0.872312	valid_0's binary_logloss: 0.422769
# [149]	valid_0's auc: 0.872306	valid_0's binary_logloss: 0.422764
# [150]	valid_0's auc: 0.872292	valid_0's binary_logloss: 0.422755
# [151]	valid_0's auc: 0.872285	valid_0's binary_logloss: 0.422766
# [152]	valid_0's auc: 0.87229	valid_0's binary_logloss: 0.422745
# [153]	valid_0's auc: 0.872274	valid_0's binary_logloss: 0.422731
# [154]	valid_0's auc: 0.87227	valid_0's binary_logloss: 0.422728
# [155]	valid_0's auc: 0.872301	valid_0's binary_logloss: 0.42269
# [156]	valid_0's auc: 0.872299	valid_0's binary_logloss: 0.422664
# [157]	valid_0's auc: 0.872185	valid_0's binary_logloss: 0.42268
# [158]	valid_0's auc: 0.872204	valid_0's binary_logloss: 0.422652
# [159]	valid_0's auc: 0.872201	valid_0's binary_logloss: 0.422629
# [160]	valid_0's auc: 0.872208	valid_0's binary_logloss: 0.422613
# [161]	valid_0's auc: 0.872208	valid_0's binary_logloss: 0.422579
# [162]	valid_0's auc: 0.872208	valid_0's binary_logloss: 0.422567
# [163]	valid_0's auc: 0.872141	valid_0's binary_logloss: 0.422588
# [164]	valid_0's auc: 0.872138	valid_0's binary_logloss: 0.42257
# [165]	valid_0's auc: 0.872158	valid_0's binary_logloss: 0.422541
# [166]	valid_0's auc: 0.872164	valid_0's binary_logloss: 0.422535
# [167]	valid_0's auc: 0.872182	valid_0's binary_logloss: 0.422508
# [168]	valid_0's auc: 0.87215	valid_0's binary_logloss: 0.422521
# [169]	valid_0's auc: 0.872139	valid_0's binary_logloss: 0.422512
# [170]	valid_0's auc: 0.87213	valid_0's binary_logloss: 0.422482
# [171]	valid_0's auc: 0.872129	valid_0's binary_logloss: 0.422451
# [172]	valid_0's auc: 0.872153	valid_0's binary_logloss: 0.422411
# [173]	valid_0's auc: 0.872118	valid_0's binary_logloss: 0.422415
# [174]	valid_0's auc: 0.872102	valid_0's binary_logloss: 0.422413
# [175]	valid_0's auc: 0.872104	valid_0's binary_logloss: 0.422387
# [176]	valid_0's auc: 0.872079	valid_0's binary_logloss: 0.422389
# [177]	valid_0's auc: 0.872077	valid_0's binary_logloss: 0.422369
# [178]	valid_0's auc: 0.872048	valid_0's binary_logloss: 0.422374
# [179]	valid_0's auc: 0.872062	valid_0's binary_logloss: 0.422369
# [180]	valid_0's auc: 0.872058	valid_0's binary_logloss: 0.422344
# [181]	valid_0's auc: 0.872067	valid_0's binary_logloss: 0.422325
# [182]	valid_0's auc: 0.872068	valid_0's binary_logloss: 0.422312
# [183]	valid_0's auc: 0.871991	valid_0's binary_logloss: 0.422332
# [184]	valid_0's auc: 0.871998	valid_0's binary_logloss: 0.422336
# [185]	valid_0's auc: 0.872013	valid_0's binary_logloss: 0.422319
# [186]	valid_0's auc: 0.872004	valid_0's binary_logloss: 0.42228
# [187]	valid_0's auc: 0.871993	valid_0's binary_logloss: 0.422268
# [188]	valid_0's auc: 0.872016	valid_0's binary_logloss: 0.422252
# [189]	valid_0's auc: 0.872014	valid_0's binary_logloss: 0.422238
# [190]	valid_0's auc: 0.87203	valid_0's binary_logloss: 0.422203
# [191]	valid_0's auc: 0.872011	valid_0's binary_logloss: 0.422206
# [192]	valid_0's auc: 0.872005	valid_0's binary_logloss: 0.422215
# [193]	valid_0's auc: 0.872016	valid_0's binary_logloss: 0.422188
# [194]	valid_0's auc: 0.871992	valid_0's binary_logloss: 0.422189
# [195]	valid_0's auc: 0.872007	valid_0's binary_logloss: 0.422183
# [196]	valid_0's auc: 0.87201	valid_0's binary_logloss: 0.422172
# [197]	valid_0's auc: 0.872035	valid_0's binary_logloss: 0.422134
# [198]	valid_0's auc: 0.872031	valid_0's binary_logloss: 0.422124
# [199]	valid_0's auc: 0.87199	valid_0's binary_logloss: 0.422132
# [200]	valid_0's auc: 0.872009	valid_0's binary_logloss: 0.42213
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.86540
# [1]	validation_0-auc:0.86597
# [2]	validation_0-auc:0.86643
# [3]	validation_0-auc:0.86696
# [4]	validation_0-auc:0.86756
# [5]	validation_0-auc:0.86765
# [6]	validation_0-auc:0.86804
# [7]	validation_0-auc:0.86819
# [8]	validation_0-auc:0.86826
# [9]	validation_0-auc:0.86843
# [10]	validation_0-auc:0.86866
# [11]	validation_0-auc:0.86885
# [12]	validation_0-auc:0.86908
# [13]	validation_0-auc:0.86945
# [14]	validation_0-auc:0.86953
# [15]	validation_0-auc:0.86977
# [16]	validation_0-auc:0.86984
# [17]	validation_0-auc:0.87018
# [18]	validation_0-auc:0.87028
# [19]	validation_0-auc:0.87031
# [20]	validation_0-auc:0.87035
# [21]	validation_0-auc:0.87046
# [22]	validation_0-auc:0.87049
# [23]	validation_0-auc:0.87054
# [24]	validation_0-auc:0.87068
# [25]	validation_0-auc:0.87093
# [26]	validation_0-auc:0.87094
# [27]	validation_0-auc:0.87112
# [28]	validation_0-auc:0.87137
# [29]	validation_0-auc:0.87145
# [30]	validation_0-auc:0.87152
# [31]	validation_0-auc:0.87152
# [32]	validation_0-auc:0.87161
# [33]	validation_0-auc:0.87170
# [34]	validation_0-auc:0.87172
# [35]	validation_0-auc:0.87172
# [36]	validation_0-auc:0.87174
# [37]	validation_0-auc:0.87181
# [38]	validation_0-auc:0.87188
# [39]	validation_0-auc:0.87191
# [40]	validation_0-auc:0.87196
# [41]	validation_0-auc:0.87196
# [42]	validation_0-auc:0.87209
# [43]	validation_0-auc:0.87209
# [44]	validation_0-auc:0.87215
# [45]	validation_0-auc:0.87215
# [46]	validation_0-auc:0.87219
# [47]	validation_0-auc:0.87219
# [48]	validation_0-auc:0.87221
# [49]	validation_0-auc:0.87220
# [50]	validation_0-auc:0.87226
# [51]	validation_0-auc:0.87236
# [52]	validation_0-auc:0.87241
# [53]	validation_0-auc:0.87240
# [54]	validation_0-auc:0.87244
# [55]	validation_0-auc:0.87246
# [56]	validation_0-auc:0.87248
# [57]	validation_0-auc:0.87246
# [58]	validation_0-auc:0.87245
# [59]	validation_0-auc:0.87254
# [60]	validation_0-auc:0.87251
# [61]	validation_0-auc:0.87252
# [62]	validation_0-auc:0.87248
# [63]	validation_0-auc:0.87251
# [64]	validation_0-auc:0.87250
# [65]	validation_0-auc:0.87246
# [66]	validation_0-auc:0.87246
# [67]	validation_0-auc:0.87248
# [68]	validation_0-auc:0.87244
# [69]	validation_0-auc:0.87244
# [70]	validation_0-auc:0.87242
# [71]	validation_0-auc:0.87241
# [72]	validation_0-auc:0.87231
# [73]	validation_0-auc:0.87236
# [74]	validation_0-auc:0.87237
# [75]	validation_0-auc:0.87240
# [76]	validation_0-auc:0.87239
# [77]	validation_0-auc:0.87248
# [78]	validation_0-auc:0.87246
# [79]	validation_0-auc:0.87248
# [80]	validation_0-auc:0.87250
# [81]	validation_0-auc:0.87247
# [82]	validation_0-auc:0.87245
# [83]	validation_0-auc:0.87246
# [84]	validation_0-auc:0.87247
# [85]	validation_0-auc:0.87250
# [86]	validation_0-auc:0.87249
# [87]	validation_0-auc:0.87250
# [88]	validation_0-auc:0.87248
# [89]	validation_0-auc:0.87250
# [90]	validation_0-auc:0.87253
# [91]	validation_0-auc:0.87253
# [92]	validation_0-auc:0.87253
# [93]	validation_0-auc:0.87255
# [94]	validation_0-auc:0.87256
# [95]	validation_0-auc:0.87252
# [96]	validation_0-auc:0.87251
# [97]	validation_0-auc:0.87254
# [98]	validation_0-auc:0.87257
# [99]	validation_0-auc:0.87255
# ROC_AUC
# ***************************
# 0.8725189212473874
# None
# [1]	valid_0's auc: 0.869232	valid_0's binary_logloss: 0.651535
# [2]	valid_0's auc: 0.869649	valid_0's binary_logloss: 0.61732
# [3]	valid_0's auc: 0.870209	valid_0's binary_logloss: 0.588807
# [4]	valid_0's auc: 0.870185	valid_0's binary_logloss: 0.564915
# [5]	valid_0's auc: 0.870426	valid_0's binary_logloss: 0.54483
# [6]	valid_0's auc: 0.870485	valid_0's binary_logloss: 0.527747
# [7]	valid_0's auc: 0.870636	valid_0's binary_logloss: 0.513155
# [8]	valid_0's auc: 0.870717	valid_0's binary_logloss: 0.500692
# [9]	valid_0's auc: 0.871302	valid_0's binary_logloss: 0.49004
# [10]	valid_0's auc: 0.871375	valid_0's binary_logloss: 0.480951
# [11]	valid_0's auc: 0.871533	valid_0's binary_logloss: 0.473024
# [12]	valid_0's auc: 0.871687	valid_0's binary_logloss: 0.466135
# [13]	valid_0's auc: 0.8718	valid_0's binary_logloss: 0.460268
# [14]	valid_0's auc: 0.87211	valid_0's binary_logloss: 0.455235
# [15]	valid_0's auc: 0.872245	valid_0's binary_logloss: 0.450749
# [16]	valid_0's auc: 0.872365	valid_0's binary_logloss: 0.446924
# [17]	valid_0's auc: 0.872374	valid_0's binary_logloss: 0.443692
# [18]	valid_0's auc: 0.872596	valid_0's binary_logloss: 0.440828
# [19]	valid_0's auc: 0.872699	valid_0's binary_logloss: 0.438372
# [20]	valid_0's auc: 0.872827	valid_0's binary_logloss: 0.436219
# [21]	valid_0's auc: 0.872883	valid_0's binary_logloss: 0.43442
# [22]	valid_0's auc: 0.872904	valid_0's binary_logloss: 0.432935
# [23]	valid_0's auc: 0.873213	valid_0's binary_logloss: 0.431523
# [24]	valid_0's auc: 0.873265	valid_0's binary_logloss: 0.430327
# [25]	valid_0's auc: 0.873339	valid_0's binary_logloss: 0.429288
# [26]	valid_0's auc: 0.873442	valid_0's binary_logloss: 0.428339
# [27]	valid_0's auc: 0.873589	valid_0's binary_logloss: 0.427562
# [28]	valid_0's auc: 0.873556	valid_0's binary_logloss: 0.42694
# [29]	valid_0's auc: 0.873657	valid_0's binary_logloss: 0.426352
# [30]	valid_0's auc: 0.87382	valid_0's binary_logloss: 0.425764
# [31]	valid_0's auc: 0.873884	valid_0's binary_logloss: 0.425379
# [32]	valid_0's auc: 0.873943	valid_0's binary_logloss: 0.424951
# [33]	valid_0's auc: 0.87389	valid_0's binary_logloss: 0.424557
# [34]	valid_0's auc: 0.87392	valid_0's binary_logloss: 0.424275
# [35]	valid_0's auc: 0.87393	valid_0's binary_logloss: 0.424017
# [36]	valid_0's auc: 0.874089	valid_0's binary_logloss: 0.423762
# [37]	valid_0's auc: 0.874135	valid_0's binary_logloss: 0.423567
# [38]	valid_0's auc: 0.874142	valid_0's binary_logloss: 0.423448
# [39]	valid_0's auc: 0.874091	valid_0's binary_logloss: 0.423303
# [40]	valid_0's auc: 0.874099	valid_0's binary_logloss: 0.423149
# [41]	valid_0's auc: 0.87416	valid_0's binary_logloss: 0.423037
# [42]	valid_0's auc: 0.874184	valid_0's binary_logloss: 0.42292
# [43]	valid_0's auc: 0.874159	valid_0's binary_logloss: 0.422848
# [44]	valid_0's auc: 0.874208	valid_0's binary_logloss: 0.42273
# [45]	valid_0's auc: 0.874127	valid_0's binary_logloss: 0.422693
# [46]	valid_0's auc: 0.874197	valid_0's binary_logloss: 0.422597
# [47]	valid_0's auc: 0.874255	valid_0's binary_logloss: 0.422477
# [48]	valid_0's auc: 0.874229	valid_0's binary_logloss: 0.422412
# [49]	valid_0's auc: 0.874308	valid_0's binary_logloss: 0.422271
# [50]	valid_0's auc: 0.874335	valid_0's binary_logloss: 0.422159
# [51]	valid_0's auc: 0.874376	valid_0's binary_logloss: 0.422077
# [52]	valid_0's auc: 0.874395	valid_0's binary_logloss: 0.422017
# [53]	valid_0's auc: 0.874388	valid_0's binary_logloss: 0.421899
# [54]	valid_0's auc: 0.874528	valid_0's binary_logloss: 0.421871
# [55]	valid_0's auc: 0.874539	valid_0's binary_logloss: 0.421824
# [56]	valid_0's auc: 0.874513	valid_0's binary_logloss: 0.421772
# [57]	valid_0's auc: 0.874539	valid_0's binary_logloss: 0.421715
# [58]	valid_0's auc: 0.874566	valid_0's binary_logloss: 0.421611
# [59]	valid_0's auc: 0.874571	valid_0's binary_logloss: 0.421596
# [60]	valid_0's auc: 0.874513	valid_0's binary_logloss: 0.421571
# [61]	valid_0's auc: 0.87451	valid_0's binary_logloss: 0.421558
# [62]	valid_0's auc: 0.874539	valid_0's binary_logloss: 0.421538
# [63]	valid_0's auc: 0.874565	valid_0's binary_logloss: 0.421513
# [64]	valid_0's auc: 0.874577	valid_0's binary_logloss: 0.421485
# [65]	valid_0's auc: 0.874585	valid_0's binary_logloss: 0.421471
# [66]	valid_0's auc: 0.87455	valid_0's binary_logloss: 0.421464
# [67]	valid_0's auc: 0.874537	valid_0's binary_logloss: 0.421439
# [68]	valid_0's auc: 0.874486	valid_0's binary_logloss: 0.421434
# [69]	valid_0's auc: 0.874477	valid_0's binary_logloss: 0.421417
# [70]	valid_0's auc: 0.874481	valid_0's binary_logloss: 0.421409
# [71]	valid_0's auc: 0.874465	valid_0's binary_logloss: 0.421405
# [72]	valid_0's auc: 0.874497	valid_0's binary_logloss: 0.421349
# [73]	valid_0's auc: 0.874474	valid_0's binary_logloss: 0.421298
# [74]	valid_0's auc: 0.874501	valid_0's binary_logloss: 0.421286
# [75]	valid_0's auc: 0.874492	valid_0's binary_logloss: 0.421243
# [76]	valid_0's auc: 0.874421	valid_0's binary_logloss: 0.421231
# [77]	valid_0's auc: 0.874417	valid_0's binary_logloss: 0.421216
# [78]	valid_0's auc: 0.874455	valid_0's binary_logloss: 0.421196
# [79]	valid_0's auc: 0.874486	valid_0's binary_logloss: 0.421159
# [80]	valid_0's auc: 0.874479	valid_0's binary_logloss: 0.421144
# [81]	valid_0's auc: 0.87444	valid_0's binary_logloss: 0.421124
# [82]	valid_0's auc: 0.874449	valid_0's binary_logloss: 0.421046
# [83]	valid_0's auc: 0.874457	valid_0's binary_logloss: 0.421011
# [84]	valid_0's auc: 0.874476	valid_0's binary_logloss: 0.420988
# [85]	valid_0's auc: 0.874471	valid_0's binary_logloss: 0.420971
# [86]	valid_0's auc: 0.874503	valid_0's binary_logloss: 0.420928
# [87]	valid_0's auc: 0.874482	valid_0's binary_logloss: 0.420865
# [88]	valid_0's auc: 0.874398	valid_0's binary_logloss: 0.420868
# [89]	valid_0's auc: 0.874408	valid_0's binary_logloss: 0.420812
# [90]	valid_0's auc: 0.874413	valid_0's binary_logloss: 0.420813
# [91]	valid_0's auc: 0.874422	valid_0's binary_logloss: 0.420777
# [92]	valid_0's auc: 0.874386	valid_0's binary_logloss: 0.420768
# [93]	valid_0's auc: 0.874274	valid_0's binary_logloss: 0.420805
# [94]	valid_0's auc: 0.874273	valid_0's binary_logloss: 0.420771
# [95]	valid_0's auc: 0.874273	valid_0's binary_logloss: 0.420755
# [96]	valid_0's auc: 0.874264	valid_0's binary_logloss: 0.420767
# [97]	valid_0's auc: 0.874279	valid_0's binary_logloss: 0.420746
# [98]	valid_0's auc: 0.874262	valid_0's binary_logloss: 0.420725
# [99]	valid_0's auc: 0.874277	valid_0's binary_logloss: 0.4207
# [100]	valid_0's auc: 0.874313	valid_0's binary_logloss: 0.420677
# [101]	valid_0's auc: 0.874313	valid_0's binary_logloss: 0.420638
# [102]	valid_0's auc: 0.874295	valid_0's binary_logloss: 0.420648
# [103]	valid_0's auc: 0.874292	valid_0's binary_logloss: 0.420635
# [104]	valid_0's auc: 0.874285	valid_0's binary_logloss: 0.420614
# [105]	valid_0's auc: 0.874274	valid_0's binary_logloss: 0.420601
# [106]	valid_0's auc: 0.874269	valid_0's binary_logloss: 0.420604
# [107]	valid_0's auc: 0.874303	valid_0's binary_logloss: 0.420567
# [108]	valid_0's auc: 0.874252	valid_0's binary_logloss: 0.420571
# [109]	valid_0's auc: 0.874245	valid_0's binary_logloss: 0.420536
# [110]	valid_0's auc: 0.874235	valid_0's binary_logloss: 0.420518
# [111]	valid_0's auc: 0.874224	valid_0's binary_logloss: 0.420499
# [112]	valid_0's auc: 0.874252	valid_0's binary_logloss: 0.420469
# [113]	valid_0's auc: 0.874261	valid_0's binary_logloss: 0.420449
# [114]	valid_0's auc: 0.874291	valid_0's binary_logloss: 0.420427
# [115]	valid_0's auc: 0.87429	valid_0's binary_logloss: 0.42041
# [116]	valid_0's auc: 0.874283	valid_0's binary_logloss: 0.420391
# [117]	valid_0's auc: 0.874265	valid_0's binary_logloss: 0.420393
# [118]	valid_0's auc: 0.87425	valid_0's binary_logloss: 0.420384
# [119]	valid_0's auc: 0.874212	valid_0's binary_logloss: 0.420381
# [120]	valid_0's auc: 0.874153	valid_0's binary_logloss: 0.420382
# [121]	valid_0's auc: 0.874168	valid_0's binary_logloss: 0.420336
# [122]	valid_0's auc: 0.874132	valid_0's binary_logloss: 0.420344
# [123]	valid_0's auc: 0.874255	valid_0's binary_logloss: 0.4203
# [124]	valid_0's auc: 0.87428	valid_0's binary_logloss: 0.420282
# [125]	valid_0's auc: 0.874279	valid_0's binary_logloss: 0.420274
# [126]	valid_0's auc: 0.874252	valid_0's binary_logloss: 0.420287
# [127]	valid_0's auc: 0.874274	valid_0's binary_logloss: 0.420249
# [128]	valid_0's auc: 0.874261	valid_0's binary_logloss: 0.420241
# [129]	valid_0's auc: 0.874295	valid_0's binary_logloss: 0.420234
# [130]	valid_0's auc: 0.874302	valid_0's binary_logloss: 0.420208
# [131]	valid_0's auc: 0.874301	valid_0's binary_logloss: 0.420182
# [132]	valid_0's auc: 0.874298	valid_0's binary_logloss: 0.420156
# [133]	valid_0's auc: 0.874288	valid_0's binary_logloss: 0.420135
# [134]	valid_0's auc: 0.874282	valid_0's binary_logloss: 0.420117
# [135]	valid_0's auc: 0.874256	valid_0's binary_logloss: 0.42011
# [136]	valid_0's auc: 0.874264	valid_0's binary_logloss: 0.420092
# [137]	valid_0's auc: 0.874247	valid_0's binary_logloss: 0.420093
# [138]	valid_0's auc: 0.874236	valid_0's binary_logloss: 0.420049
# [139]	valid_0's auc: 0.874239	valid_0's binary_logloss: 0.420026
# [140]	valid_0's auc: 0.874224	valid_0's binary_logloss: 0.420006
# [141]	valid_0's auc: 0.874237	valid_0's binary_logloss: 0.419993
# [142]	valid_0's auc: 0.874258	valid_0's binary_logloss: 0.41995
# [143]	valid_0's auc: 0.874264	valid_0's binary_logloss: 0.419933
# [144]	valid_0's auc: 0.874252	valid_0's binary_logloss: 0.419903
# [145]	valid_0's auc: 0.874237	valid_0's binary_logloss: 0.419879
# [146]	valid_0's auc: 0.874216	valid_0's binary_logloss: 0.419883
# [147]	valid_0's auc: 0.874209	valid_0's binary_logloss: 0.419871
# [148]	valid_0's auc: 0.874208	valid_0's binary_logloss: 0.419876
# [149]	valid_0's auc: 0.874208	valid_0's binary_logloss: 0.419875
# [150]	valid_0's auc: 0.874197	valid_0's binary_logloss: 0.41987
# [151]	valid_0's auc: 0.874183	valid_0's binary_logloss: 0.419879
# [152]	valid_0's auc: 0.874199	valid_0's binary_logloss: 0.419864
# [153]	valid_0's auc: 0.874241	valid_0's binary_logloss: 0.419845
# [154]	valid_0's auc: 0.874247	valid_0's binary_logloss: 0.419824
# [155]	valid_0's auc: 0.874249	valid_0's binary_logloss: 0.419795
# [156]	valid_0's auc: 0.874235	valid_0's binary_logloss: 0.419797
# [157]	valid_0's auc: 0.874246	valid_0's binary_logloss: 0.419786
# [158]	valid_0's auc: 0.874249	valid_0's binary_logloss: 0.419771
# [159]	valid_0's auc: 0.874243	valid_0's binary_logloss: 0.419764
# [160]	valid_0's auc: 0.874231	valid_0's binary_logloss: 0.419748
# [161]	valid_0's auc: 0.87424	valid_0's binary_logloss: 0.419732
# [162]	valid_0's auc: 0.874182	valid_0's binary_logloss: 0.419735
# [163]	valid_0's auc: 0.874157	valid_0's binary_logloss: 0.419758
# [164]	valid_0's auc: 0.874123	valid_0's binary_logloss: 0.419764
# [165]	valid_0's auc: 0.874136	valid_0's binary_logloss: 0.419752
# [166]	valid_0's auc: 0.874124	valid_0's binary_logloss: 0.419739
# [167]	valid_0's auc: 0.874108	valid_0's binary_logloss: 0.419728
# [168]	valid_0's auc: 0.874086	valid_0's binary_logloss: 0.419725
# [169]	valid_0's auc: 0.874083	valid_0's binary_logloss: 0.419724
# [170]	valid_0's auc: 0.874101	valid_0's binary_logloss: 0.419711
# [171]	valid_0's auc: 0.874103	valid_0's binary_logloss: 0.4197
# [172]	valid_0's auc: 0.87409	valid_0's binary_logloss: 0.419685
# [173]	valid_0's auc: 0.874095	valid_0's binary_logloss: 0.419673
# [174]	valid_0's auc: 0.874063	valid_0's binary_logloss: 0.419678
# [175]	valid_0's auc: 0.874021	valid_0's binary_logloss: 0.419681
# [176]	valid_0's auc: 0.874024	valid_0's binary_logloss: 0.419659
# [177]	valid_0's auc: 0.874006	valid_0's binary_logloss: 0.419667
# [178]	valid_0's auc: 0.873971	valid_0's binary_logloss: 0.419627
# [179]	valid_0's auc: 0.87394	valid_0's binary_logloss: 0.419631
# [180]	valid_0's auc: 0.873959	valid_0's binary_logloss: 0.419624
# [181]	valid_0's auc: 0.873955	valid_0's binary_logloss: 0.419609
# [182]	valid_0's auc: 0.873964	valid_0's binary_logloss: 0.419579
# [183]	valid_0's auc: 0.873958	valid_0's binary_logloss: 0.419554
# [184]	valid_0's auc: 0.873976	valid_0's binary_logloss: 0.41949
# [185]	valid_0's auc: 0.873972	valid_0's binary_logloss: 0.419479
# [186]	valid_0's auc: 0.873968	valid_0's binary_logloss: 0.419469
# [187]	valid_0's auc: 0.873951	valid_0's binary_logloss: 0.41948
# [188]	valid_0's auc: 0.873945	valid_0's binary_logloss: 0.419456
# [189]	valid_0's auc: 0.873931	valid_0's binary_logloss: 0.419468
# [190]	valid_0's auc: 0.873942	valid_0's binary_logloss: 0.41946
# [191]	valid_0's auc: 0.873941	valid_0's binary_logloss: 0.419446
# [192]	valid_0's auc: 0.873955	valid_0's binary_logloss: 0.419434
# [193]	valid_0's auc: 0.873951	valid_0's binary_logloss: 0.419426
# [194]	valid_0's auc: 0.873952	valid_0's binary_logloss: 0.419431
# [195]	valid_0's auc: 0.873968	valid_0's binary_logloss: 0.41941
# [196]	valid_0's auc: 0.873962	valid_0's binary_logloss: 0.41938
# [197]	valid_0's auc: 0.873958	valid_0's binary_logloss: 0.419335
# [198]	valid_0's auc: 0.87395	valid_0's binary_logloss: 0.419331
# [199]	valid_0's auc: 0.873933	valid_0's binary_logloss: 0.419323
# [200]	valid_0's auc: 0.87391	valid_0's binary_logloss: 0.419313
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.86637
# [1]	validation_0-auc:0.86700
# [2]	validation_0-auc:0.86779
# [3]	validation_0-auc:0.86789
# [4]	validation_0-auc:0.86848
# [5]	validation_0-auc:0.86889
# [6]	validation_0-auc:0.86977
# [7]	validation_0-auc:0.87001
# [8]	validation_0-auc:0.86987
# [9]	validation_0-auc:0.87015
# [10]	validation_0-auc:0.87037
# [11]	validation_0-auc:0.87081
# [12]	validation_0-auc:0.87094
# [13]	validation_0-auc:0.87100
# [14]	validation_0-auc:0.87152
# [15]	validation_0-auc:0.87160
# [16]	validation_0-auc:0.87170
# [17]	validation_0-auc:0.87182
# [18]	validation_0-auc:0.87200
# [19]	validation_0-auc:0.87213
# [20]	validation_0-auc:0.87220
# [21]	validation_0-auc:0.87220
# [22]	validation_0-auc:0.87226
# [23]	validation_0-auc:0.87235
# [24]	validation_0-auc:0.87249
# [25]	validation_0-auc:0.87262
# [26]	validation_0-auc:0.87273
# [27]	validation_0-auc:0.87299
# [28]	validation_0-auc:0.87312
# [29]	validation_0-auc:0.87309
# [30]	validation_0-auc:0.87317
# [31]	validation_0-auc:0.87326
# [32]	validation_0-auc:0.87324
# [33]	validation_0-auc:0.87333
# [34]	validation_0-auc:0.87322
# [35]	validation_0-auc:0.87339
# [36]	validation_0-auc:0.87342
# [37]	validation_0-auc:0.87372
# [38]	validation_0-auc:0.87377
# [39]	validation_0-auc:0.87374
# [40]	validation_0-auc:0.87374
# [41]	validation_0-auc:0.87379
# [42]	validation_0-auc:0.87387
# [43]	validation_0-auc:0.87400
# [44]	validation_0-auc:0.87398
# [45]	validation_0-auc:0.87405
# [46]	validation_0-auc:0.87408
# [47]	validation_0-auc:0.87409
# [48]	validation_0-auc:0.87409
# [49]	validation_0-auc:0.87416
# [50]	validation_0-auc:0.87417
# [51]	validation_0-auc:0.87417
# [52]	validation_0-auc:0.87414
# [53]	validation_0-auc:0.87419
# [54]	validation_0-auc:0.87426
# [55]	validation_0-auc:0.87424
# [56]	validation_0-auc:0.87428
# [57]	validation_0-auc:0.87425
# [58]	validation_0-auc:0.87425
# [59]	validation_0-auc:0.87430
# [60]	validation_0-auc:0.87427
# [61]	validation_0-auc:0.87426
# [62]	validation_0-auc:0.87424
# [63]	validation_0-auc:0.87420
# [64]	validation_0-auc:0.87420
# [65]	validation_0-auc:0.87423
# [66]	validation_0-auc:0.87417
# [67]	validation_0-auc:0.87414
# [68]	validation_0-auc:0.87414
# [69]	validation_0-auc:0.87416
# [70]	validation_0-auc:0.87420
# [71]	validation_0-auc:0.87418
# [72]	validation_0-auc:0.87420
# [73]	validation_0-auc:0.87421
# [74]	validation_0-auc:0.87423
# [75]	validation_0-auc:0.87427
# [76]	validation_0-auc:0.87425
# [77]	validation_0-auc:0.87419
# [78]	validation_0-auc:0.87427
# [79]	validation_0-auc:0.87425
# [80]	validation_0-auc:0.87423
# [81]	validation_0-auc:0.87421
# [82]	validation_0-auc:0.87417
# [83]	validation_0-auc:0.87421
# [84]	validation_0-auc:0.87421
# [85]	validation_0-auc:0.87423
# [86]	validation_0-auc:0.87423
# [87]	validation_0-auc:0.87419
# [88]	validation_0-auc:0.87422
# [89]	validation_0-auc:0.87421
# [90]	validation_0-auc:0.87420
# [91]	validation_0-auc:0.87422
# [92]	validation_0-auc:0.87423
# [93]	validation_0-auc:0.87425
# [94]	validation_0-auc:0.87421
# [95]	validation_0-auc:0.87421
# [96]	validation_0-auc:0.87431
# [97]	validation_0-auc:0.87429
# [98]	validation_0-auc:0.87428
# [99]	validation_0-auc:0.87430
# ROC_AUC
# ***************************
# 0.8745596005722833
# None
# [1]	valid_0's auc: 0.867738	valid_0's binary_logloss: 0.651758
# [2]	valid_0's auc: 0.867956	valid_0's binary_logloss: 0.617701
# [3]	valid_0's auc: 0.868258	valid_0's binary_logloss: 0.589376
# [4]	valid_0's auc: 0.869788	valid_0's binary_logloss: 0.565592
# [5]	valid_0's auc: 0.870289	valid_0's binary_logloss: 0.54545
# [6]	valid_0's auc: 0.870411	valid_0's binary_logloss: 0.528338
# [7]	valid_0's auc: 0.870476	valid_0's binary_logloss: 0.513981
# [8]	valid_0's auc: 0.870689	valid_0's binary_logloss: 0.501525
# [9]	valid_0's auc: 0.871258	valid_0's binary_logloss: 0.490899
# [10]	valid_0's auc: 0.871649	valid_0's binary_logloss: 0.481757
# [11]	valid_0's auc: 0.871908	valid_0's binary_logloss: 0.473849
# [12]	valid_0's auc: 0.871957	valid_0's binary_logloss: 0.467162
# [13]	valid_0's auc: 0.872037	valid_0's binary_logloss: 0.461352
# [14]	valid_0's auc: 0.872089	valid_0's binary_logloss: 0.456378
# [15]	valid_0's auc: 0.872093	valid_0's binary_logloss: 0.451997
# [16]	valid_0's auc: 0.872147	valid_0's binary_logloss: 0.448192
# [17]	valid_0's auc: 0.872287	valid_0's binary_logloss: 0.444874
# [18]	valid_0's auc: 0.872298	valid_0's binary_logloss: 0.442093
# [19]	valid_0's auc: 0.872429	valid_0's binary_logloss: 0.439733
# [20]	valid_0's auc: 0.872517	valid_0's binary_logloss: 0.437681
# [21]	valid_0's auc: 0.872834	valid_0's binary_logloss: 0.4358
# [22]	valid_0's auc: 0.872897	valid_0's binary_logloss: 0.43418
# [23]	valid_0's auc: 0.872902	valid_0's binary_logloss: 0.432874
# [24]	valid_0's auc: 0.873039	valid_0's binary_logloss: 0.431634
# [25]	valid_0's auc: 0.872916	valid_0's binary_logloss: 0.430647
# [26]	valid_0's auc: 0.87301	valid_0's binary_logloss: 0.429738
# [27]	valid_0's auc: 0.873062	valid_0's binary_logloss: 0.428997
# [28]	valid_0's auc: 0.873074	valid_0's binary_logloss: 0.42841
# [29]	valid_0's auc: 0.873129	valid_0's binary_logloss: 0.427853
# [30]	valid_0's auc: 0.873191	valid_0's binary_logloss: 0.427191
# [31]	valid_0's auc: 0.873309	valid_0's binary_logloss: 0.426703
# [32]	valid_0's auc: 0.873303	valid_0's binary_logloss: 0.426372
# [33]	valid_0's auc: 0.873352	valid_0's binary_logloss: 0.425952
# [34]	valid_0's auc: 0.873351	valid_0's binary_logloss: 0.425667
# [35]	valid_0's auc: 0.873412	valid_0's binary_logloss: 0.425385
# [36]	valid_0's auc: 0.873508	valid_0's binary_logloss: 0.425161
# [37]	valid_0's auc: 0.873533	valid_0's binary_logloss: 0.424962
# [38]	valid_0's auc: 0.87354	valid_0's binary_logloss: 0.424803
# [39]	valid_0's auc: 0.873571	valid_0's binary_logloss: 0.42464
# [40]	valid_0's auc: 0.873602	valid_0's binary_logloss: 0.424532
# [41]	valid_0's auc: 0.873589	valid_0's binary_logloss: 0.424417
# [42]	valid_0's auc: 0.873428	valid_0's binary_logloss: 0.424307
# [43]	valid_0's auc: 0.873426	valid_0's binary_logloss: 0.424228
# [44]	valid_0's auc: 0.873466	valid_0's binary_logloss: 0.424175
# [45]	valid_0's auc: 0.873473	valid_0's binary_logloss: 0.424092
# [46]	valid_0's auc: 0.873548	valid_0's binary_logloss: 0.424025
# [47]	valid_0's auc: 0.873614	valid_0's binary_logloss: 0.42389
# [48]	valid_0's auc: 0.873658	valid_0's binary_logloss: 0.423777
# [49]	valid_0's auc: 0.873737	valid_0's binary_logloss: 0.42369
# [50]	valid_0's auc: 0.873685	valid_0's binary_logloss: 0.423657
# [51]	valid_0's auc: 0.873723	valid_0's binary_logloss: 0.423579
# [52]	valid_0's auc: 0.873746	valid_0's binary_logloss: 0.423519
# [53]	valid_0's auc: 0.873819	valid_0's binary_logloss: 0.423456
# [54]	valid_0's auc: 0.873843	valid_0's binary_logloss: 0.423415
# [55]	valid_0's auc: 0.873817	valid_0's binary_logloss: 0.423318
# [56]	valid_0's auc: 0.873818	valid_0's binary_logloss: 0.423286
# [57]	valid_0's auc: 0.873827	valid_0's binary_logloss: 0.423247
# [58]	valid_0's auc: 0.873776	valid_0's binary_logloss: 0.42322
# [59]	valid_0's auc: 0.873775	valid_0's binary_logloss: 0.42319
# [60]	valid_0's auc: 0.873778	valid_0's binary_logloss: 0.423191
# [61]	valid_0's auc: 0.87374	valid_0's binary_logloss: 0.423195
# [62]	valid_0's auc: 0.873771	valid_0's binary_logloss: 0.423155
# [63]	valid_0's auc: 0.873768	valid_0's binary_logloss: 0.423131
# [64]	valid_0's auc: 0.873759	valid_0's binary_logloss: 0.423118
# [65]	valid_0's auc: 0.873761	valid_0's binary_logloss: 0.423099
# [66]	valid_0's auc: 0.873764	valid_0's binary_logloss: 0.423089
# [67]	valid_0's auc: 0.873708	valid_0's binary_logloss: 0.423048
# [68]	valid_0's auc: 0.873632	valid_0's binary_logloss: 0.423055
# [69]	valid_0's auc: 0.873652	valid_0's binary_logloss: 0.423033
# [70]	valid_0's auc: 0.87365	valid_0's binary_logloss: 0.423022
# [71]	valid_0's auc: 0.873561	valid_0's binary_logloss: 0.423015
# [72]	valid_0's auc: 0.87356	valid_0's binary_logloss: 0.423002
# [73]	valid_0's auc: 0.873552	valid_0's binary_logloss: 0.422991
# [74]	valid_0's auc: 0.873541	valid_0's binary_logloss: 0.422993
# [75]	valid_0's auc: 0.873503	valid_0's binary_logloss: 0.422951
# [76]	valid_0's auc: 0.873489	valid_0's binary_logloss: 0.422927
# [77]	valid_0's auc: 0.873446	valid_0's binary_logloss: 0.422934
# [78]	valid_0's auc: 0.87339	valid_0's binary_logloss: 0.422941
# [79]	valid_0's auc: 0.873367	valid_0's binary_logloss: 0.422897
# [80]	valid_0's auc: 0.873346	valid_0's binary_logloss: 0.422901
# [81]	valid_0's auc: 0.873332	valid_0's binary_logloss: 0.422877
# [82]	valid_0's auc: 0.873346	valid_0's binary_logloss: 0.422842
# [83]	valid_0's auc: 0.873356	valid_0's binary_logloss: 0.422822
# [84]	valid_0's auc: 0.873357	valid_0's binary_logloss: 0.422819
# [85]	valid_0's auc: 0.873369	valid_0's binary_logloss: 0.422805
# [86]	valid_0's auc: 0.873385	valid_0's binary_logloss: 0.422788
# [87]	valid_0's auc: 0.873413	valid_0's binary_logloss: 0.422753
# [88]	valid_0's auc: 0.873443	valid_0's binary_logloss: 0.422741
# [89]	valid_0's auc: 0.87341	valid_0's binary_logloss: 0.422741
# [90]	valid_0's auc: 0.873401	valid_0's binary_logloss: 0.42275
# [91]	valid_0's auc: 0.873398	valid_0's binary_logloss: 0.422737
# [92]	valid_0's auc: 0.873405	valid_0's binary_logloss: 0.422729
# [93]	valid_0's auc: 0.873381	valid_0's binary_logloss: 0.422728
# [94]	valid_0's auc: 0.873369	valid_0's binary_logloss: 0.422709
# [95]	valid_0's auc: 0.873365	valid_0's binary_logloss: 0.422687
# [96]	valid_0's auc: 0.87336	valid_0's binary_logloss: 0.422653
# [97]	valid_0's auc: 0.873345	valid_0's binary_logloss: 0.422649
# [98]	valid_0's auc: 0.87333	valid_0's binary_logloss: 0.422648
# [99]	valid_0's auc: 0.873403	valid_0's binary_logloss: 0.422617
# [100]	valid_0's auc: 0.873417	valid_0's binary_logloss: 0.422615
# [101]	valid_0's auc: 0.873412	valid_0's binary_logloss: 0.422578
# [102]	valid_0's auc: 0.873469	valid_0's binary_logloss: 0.422548
# [103]	valid_0's auc: 0.873447	valid_0's binary_logloss: 0.422563
# [104]	valid_0's auc: 0.873458	valid_0's binary_logloss: 0.422541
# [105]	valid_0's auc: 0.873436	valid_0's binary_logloss: 0.422536
# [106]	valid_0's auc: 0.873418	valid_0's binary_logloss: 0.422519
# [107]	valid_0's auc: 0.873405	valid_0's binary_logloss: 0.422508
# [108]	valid_0's auc: 0.873387	valid_0's binary_logloss: 0.422457
# [109]	valid_0's auc: 0.873331	valid_0's binary_logloss: 0.422422
# [110]	valid_0's auc: 0.873374	valid_0's binary_logloss: 0.422385
# [111]	valid_0's auc: 0.873355	valid_0's binary_logloss: 0.42241
# [112]	valid_0's auc: 0.873333	valid_0's binary_logloss: 0.42241
# [113]	valid_0's auc: 0.873341	valid_0's binary_logloss: 0.422384
# [114]	valid_0's auc: 0.873319	valid_0's binary_logloss: 0.422386
# [115]	valid_0's auc: 0.873314	valid_0's binary_logloss: 0.422385
# [116]	valid_0's auc: 0.873278	valid_0's binary_logloss: 0.422383
# [117]	valid_0's auc: 0.873275	valid_0's binary_logloss: 0.422379
# [118]	valid_0's auc: 0.873294	valid_0's binary_logloss: 0.422359
# [119]	valid_0's auc: 0.873297	valid_0's binary_logloss: 0.422341
# [120]	valid_0's auc: 0.873257	valid_0's binary_logloss: 0.422328
# [121]	valid_0's auc: 0.873227	valid_0's binary_logloss: 0.422334
# [122]	valid_0's auc: 0.873247	valid_0's binary_logloss: 0.422307
# [123]	valid_0's auc: 0.873335	valid_0's binary_logloss: 0.422273
# [124]	valid_0's auc: 0.873334	valid_0's binary_logloss: 0.422283
# [125]	valid_0's auc: 0.873331	valid_0's binary_logloss: 0.422265
# [126]	valid_0's auc: 0.873361	valid_0's binary_logloss: 0.422245
# [127]	valid_0's auc: 0.873348	valid_0's binary_logloss: 0.422242
# [128]	valid_0's auc: 0.873337	valid_0's binary_logloss: 0.422226
# [129]	valid_0's auc: 0.873327	valid_0's binary_logloss: 0.422226
# [130]	valid_0's auc: 0.873317	valid_0's binary_logloss: 0.422216
# [131]	valid_0's auc: 0.873326	valid_0's binary_logloss: 0.422193
# [132]	valid_0's auc: 0.873297	valid_0's binary_logloss: 0.422173
# [133]	valid_0's auc: 0.873312	valid_0's binary_logloss: 0.422149
# [134]	valid_0's auc: 0.873238	valid_0's binary_logloss: 0.422137
# [135]	valid_0's auc: 0.87327	valid_0's binary_logloss: 0.422113
# [136]	valid_0's auc: 0.873268	valid_0's binary_logloss: 0.422125
# [137]	valid_0's auc: 0.873256	valid_0's binary_logloss: 0.422118
# [138]	valid_0's auc: 0.873218	valid_0's binary_logloss: 0.422111
# [139]	valid_0's auc: 0.873207	valid_0's binary_logloss: 0.422095
# [140]	valid_0's auc: 0.8732	valid_0's binary_logloss: 0.422074
# [141]	valid_0's auc: 0.873216	valid_0's binary_logloss: 0.42204
# [142]	valid_0's auc: 0.873234	valid_0's binary_logloss: 0.422011
# [143]	valid_0's auc: 0.873252	valid_0's binary_logloss: 0.421998
# [144]	valid_0's auc: 0.873263	valid_0's binary_logloss: 0.422001
# [145]	valid_0's auc: 0.873223	valid_0's binary_logloss: 0.422002
# [146]	valid_0's auc: 0.87316	valid_0's binary_logloss: 0.421974
# [147]	valid_0's auc: 0.873163	valid_0's binary_logloss: 0.421944
# [148]	valid_0's auc: 0.873167	valid_0's binary_logloss: 0.421922
# [149]	valid_0's auc: 0.873154	valid_0's binary_logloss: 0.421916
# [150]	valid_0's auc: 0.873155	valid_0's binary_logloss: 0.421895
# [151]	valid_0's auc: 0.873137	valid_0's binary_logloss: 0.421884
# [152]	valid_0's auc: 0.873154	valid_0's binary_logloss: 0.421856
# [153]	valid_0's auc: 0.873164	valid_0's binary_logloss: 0.4218
# [154]	valid_0's auc: 0.873159	valid_0's binary_logloss: 0.421789
# [155]	valid_0's auc: 0.873161	valid_0's binary_logloss: 0.421776
# [156]	valid_0's auc: 0.87316	valid_0's binary_logloss: 0.421771
# [157]	valid_0's auc: 0.873127	valid_0's binary_logloss: 0.421756
# [158]	valid_0's auc: 0.873193	valid_0's binary_logloss: 0.421721
# [159]	valid_0's auc: 0.873192	valid_0's binary_logloss: 0.421725
# [160]	valid_0's auc: 0.873149	valid_0's binary_logloss: 0.421736
# [161]	valid_0's auc: 0.873167	valid_0's binary_logloss: 0.421711
# [162]	valid_0's auc: 0.873167	valid_0's binary_logloss: 0.421692
# [163]	valid_0's auc: 0.873168	valid_0's binary_logloss: 0.4217
# [164]	valid_0's auc: 0.873149	valid_0's binary_logloss: 0.421695
# [165]	valid_0's auc: 0.873148	valid_0's binary_logloss: 0.421682
# [166]	valid_0's auc: 0.873158	valid_0's binary_logloss: 0.421649
# [167]	valid_0's auc: 0.873153	valid_0's binary_logloss: 0.421644
# [168]	valid_0's auc: 0.873133	valid_0's binary_logloss: 0.421621
# [169]	valid_0's auc: 0.873132	valid_0's binary_logloss: 0.421615
# [170]	valid_0's auc: 0.873156	valid_0's binary_logloss: 0.421573
# [171]	valid_0's auc: 0.873162	valid_0's binary_logloss: 0.421536
# [172]	valid_0's auc: 0.873158	valid_0's binary_logloss: 0.421516
# [173]	valid_0's auc: 0.873135	valid_0's binary_logloss: 0.421498
# [174]	valid_0's auc: 0.873093	valid_0's binary_logloss: 0.421494
# [175]	valid_0's auc: 0.873094	valid_0's binary_logloss: 0.421469
# [176]	valid_0's auc: 0.873105	valid_0's binary_logloss: 0.421452
# [177]	valid_0's auc: 0.873093	valid_0's binary_logloss: 0.42144
# [178]	valid_0's auc: 0.873103	valid_0's binary_logloss: 0.42144
# [179]	valid_0's auc: 0.873105	valid_0's binary_logloss: 0.421428
# [180]	valid_0's auc: 0.873065	valid_0's binary_logloss: 0.42144
# [181]	valid_0's auc: 0.87307	valid_0's binary_logloss: 0.421441
# [182]	valid_0's auc: 0.873062	valid_0's binary_logloss: 0.421422
# [183]	valid_0's auc: 0.873021	valid_0's binary_logloss: 0.421396
# [184]	valid_0's auc: 0.872967	valid_0's binary_logloss: 0.421411
# [185]	valid_0's auc: 0.872955	valid_0's binary_logloss: 0.421401
# [186]	valid_0's auc: 0.872941	valid_0's binary_logloss: 0.421408
# [187]	valid_0's auc: 0.872934	valid_0's binary_logloss: 0.421389
# [188]	valid_0's auc: 0.872937	valid_0's binary_logloss: 0.421357
# [189]	valid_0's auc: 0.872916	valid_0's binary_logloss: 0.421357
# [190]	valid_0's auc: 0.872924	valid_0's binary_logloss: 0.421357
# [191]	valid_0's auc: 0.872939	valid_0's binary_logloss: 0.421337
# [192]	valid_0's auc: 0.872921	valid_0's binary_logloss: 0.421336
# [193]	valid_0's auc: 0.872921	valid_0's binary_logloss: 0.421336
# [194]	valid_0's auc: 0.872949	valid_0's binary_logloss: 0.421314
# [195]	valid_0's auc: 0.872974	valid_0's binary_logloss: 0.421296
# [196]	valid_0's auc: 0.872976	valid_0's binary_logloss: 0.42123
# [197]	valid_0's auc: 0.873	valid_0's binary_logloss: 0.421206
# [198]	valid_0's auc: 0.872995	valid_0's binary_logloss: 0.421198
# [199]	valid_0's auc: 0.873058	valid_0's binary_logloss: 0.421139
# [200]	valid_0's auc: 0.873051	valid_0's binary_logloss: 0.421128
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.86584
# [1]	validation_0-auc:0.86762
# [2]	validation_0-auc:0.86849
# [3]	validation_0-auc:0.86855
# [4]	validation_0-auc:0.86912
# [5]	validation_0-auc:0.86956
# [6]	validation_0-auc:0.86968
# [7]	validation_0-auc:0.87014
# [8]	validation_0-auc:0.87034
# [9]	validation_0-auc:0.87051
# [10]	validation_0-auc:0.87053
# [11]	validation_0-auc:0.87091
# [12]	validation_0-auc:0.87128
# [13]	validation_0-auc:0.87153
# [14]	validation_0-auc:0.87152
# [15]	validation_0-auc:0.87172
# [16]	validation_0-auc:0.87170
# [17]	validation_0-auc:0.87170
# [18]	validation_0-auc:0.87178
# [19]	validation_0-auc:0.87189
# [20]	validation_0-auc:0.87198
# [21]	validation_0-auc:0.87214
# [22]	validation_0-auc:0.87218
# [23]	validation_0-auc:0.87230
# [24]	validation_0-auc:0.87245
# [25]	validation_0-auc:0.87255
# [26]	validation_0-auc:0.87251
# [27]	validation_0-auc:0.87268
# [28]	validation_0-auc:0.87289
# [29]	validation_0-auc:0.87285
# [30]	validation_0-auc:0.87284
# [31]	validation_0-auc:0.87284
# [32]	validation_0-auc:0.87283
# [33]	validation_0-auc:0.87302
# [34]	validation_0-auc:0.87304
# [35]	validation_0-auc:0.87319
# [36]	validation_0-auc:0.87314
# [37]	validation_0-auc:0.87296
# [38]	validation_0-auc:0.87303
# [39]	validation_0-auc:0.87313
# [40]	validation_0-auc:0.87317
# [41]	validation_0-auc:0.87319
# [42]	validation_0-auc:0.87335
# [43]	validation_0-auc:0.87343
# [44]	validation_0-auc:0.87346
# [45]	validation_0-auc:0.87347
# [46]	validation_0-auc:0.87341
# [47]	validation_0-auc:0.87343
# [48]	validation_0-auc:0.87337
# [49]	validation_0-auc:0.87335
# [50]	validation_0-auc:0.87339
# [51]	validation_0-auc:0.87341
# [52]	validation_0-auc:0.87344
# [53]	validation_0-auc:0.87345
# [54]	validation_0-auc:0.87348
# [55]	validation_0-auc:0.87343
# [56]	validation_0-auc:0.87346
# [57]	validation_0-auc:0.87345
# [58]	validation_0-auc:0.87348
# [59]	validation_0-auc:0.87347
# [60]	validation_0-auc:0.87345
# [61]	validation_0-auc:0.87341
# [62]	validation_0-auc:0.87347
# [63]	validation_0-auc:0.87348
# [64]	validation_0-auc:0.87347
# [65]	validation_0-auc:0.87345
# [66]	validation_0-auc:0.87342
# ...
# [7]	valid_0's auc: 0.872101	valid_0's binary_logloss: 0.513553
# [8]	valid_0's auc: 0.872209	valid_0's binary_logloss: 0.501173
# [9]	valid_0's auc: 0.872769	valid_0's binary_logloss: 0.490504
# [10]	valid_0's auc: 0.872864	valid_0's binary_logloss: 0.481313
# [11]	valid_0's auc: 0.872815	valid_0's binary_logloss: 0.473527
# [12]	valid_0's auc: 0.873024	valid_0's binary_logloss: 0.466799
# [13]	valid_0's auc: 0.873272	valid_0's binary_logloss: 0.460825
# [14]	valid_0's auc: 0.87355	valid_0's binary_logloss: 0.45576
# [15]	valid_0's auc: 0.873564	valid_0's binary_logloss: 0.451427
# [16]	valid_0's auc: 0.873763	valid_0's binary_logloss: 0.447653
# [17]	valid_0's auc: 0.874004	valid_0's binary_logloss: 0.444265
# [18]	valid_0's auc: 0.874086	valid_0's binary_logloss: 0.441407
# [19]	valid_0's auc: 0.874093	valid_0's binary_logloss: 0.439011
# [20]	valid_0's auc: 0.874192	valid_0's binary_logloss: 0.436784
# [21]	valid_0's auc: 0.874456	valid_0's binary_logloss: 0.43496
# [22]	valid_0's auc: 0.874556	valid_0's binary_logloss: 0.433251
# [23]	valid_0's auc: 0.87467	valid_0's binary_logloss: 0.431775
# [24]	valid_0's auc: 0.874695	valid_0's binary_logloss: 0.430514
# [25]	valid_0's auc: 0.874845	valid_0's binary_logloss: 0.429537
# [26]	valid_0's auc: 0.875012	valid_0's binary_logloss: 0.42868
# [27]	valid_0's auc: 0.875214	valid_0's binary_logloss: 0.427838
# [28]	valid_0's auc: 0.875296	valid_0's binary_logloss: 0.427093
# [29]	valid_0's auc: 0.875445	valid_0's binary_logloss: 0.42646
# [30]	valid_0's auc: 0.875493	valid_0's binary_logloss: 0.425862
# [31]	valid_0's auc: 0.875533	valid_0's binary_logloss: 0.425456
# [32]	valid_0's auc: 0.875533	valid_0's binary_logloss: 0.425008
# [33]	valid_0's auc: 0.875502	valid_0's binary_logloss: 0.424782
# [34]	valid_0's auc: 0.875541	valid_0's binary_logloss: 0.42437
# [35]	valid_0's auc: 0.875569	valid_0's binary_logloss: 0.424156
# [36]	valid_0's auc: 0.875579	valid_0's binary_logloss: 0.423835
# [37]	valid_0's auc: 0.87564	valid_0's binary_logloss: 0.423704
# [38]	valid_0's auc: 0.875643	valid_0's binary_logloss: 0.423515
# [39]	valid_0's auc: 0.875613	valid_0's binary_logloss: 0.42339
# [40]	valid_0's auc: 0.875554	valid_0's binary_logloss: 0.423268
# [41]	valid_0's auc: 0.875504	valid_0's binary_logloss: 0.423139
# [42]	valid_0's auc: 0.875542	valid_0's binary_logloss: 0.422946
# [43]	valid_0's auc: 0.875493	valid_0's binary_logloss: 0.422888
# [44]	valid_0's auc: 0.875524	valid_0's binary_logloss: 0.422792
# [45]	valid_0's auc: 0.875543	valid_0's binary_logloss: 0.422671
# [46]	valid_0's auc: 0.875586	valid_0's binary_logloss: 0.42264
# [47]	valid_0's auc: 0.875578	valid_0's binary_logloss: 0.42259
# [48]	valid_0's auc: 0.875629	valid_0's binary_logloss: 0.422477
# [49]	valid_0's auc: 0.875688	valid_0's binary_logloss: 0.422371
# [50]	valid_0's auc: 0.875684	valid_0's binary_logloss: 0.42232
# [51]	valid_0's auc: 0.875705	valid_0's binary_logloss: 0.422262
# [52]	valid_0's auc: 0.875568	valid_0's binary_logloss: 0.42216
# [53]	valid_0's auc: 0.875549	valid_0's binary_logloss: 0.422084
# [54]	valid_0's auc: 0.875527	valid_0's binary_logloss: 0.422072
# [55]	valid_0's auc: 0.875619	valid_0's binary_logloss: 0.421932
# [56]	valid_0's auc: 0.875622	valid_0's binary_logloss: 0.421866
# [57]	valid_0's auc: 0.87566	valid_0's binary_logloss: 0.421751
# [58]	valid_0's auc: 0.875684	valid_0's binary_logloss: 0.421749
# [59]	valid_0's auc: 0.875751	valid_0's binary_logloss: 0.421713
# [60]	valid_0's auc: 0.875711	valid_0's binary_logloss: 0.42168
# [61]	valid_0's auc: 0.875642	valid_0's binary_logloss: 0.421683
# [62]	valid_0's auc: 0.875604	valid_0's binary_logloss: 0.421642
# [63]	valid_0's auc: 0.875646	valid_0's binary_logloss: 0.421601
# [64]	valid_0's auc: 0.875576	valid_0's binary_logloss: 0.42158
# [65]	valid_0's auc: 0.875599	valid_0's binary_logloss: 0.421491
# [66]	valid_0's auc: 0.875499	valid_0's binary_logloss: 0.421498
# [67]	valid_0's auc: 0.875476	valid_0's binary_logloss: 0.421486
# [68]	valid_0's auc: 0.875465	valid_0's binary_logloss: 0.421427
# [69]	valid_0's auc: 0.875495	valid_0's binary_logloss: 0.421394
# [70]	valid_0's auc: 0.875481	valid_0's binary_logloss: 0.421375
# [71]	valid_0's auc: 0.875442	valid_0's binary_logloss: 0.421365
# [72]	valid_0's auc: 0.87544	valid_0's binary_logloss: 0.421345
# [73]	valid_0's auc: 0.87541	valid_0's binary_logloss: 0.421339
# [74]	valid_0's auc: 0.875295	valid_0's binary_logloss: 0.42134
# [75]	valid_0's auc: 0.875276	valid_0's binary_logloss: 0.421334
# [76]	valid_0's auc: 0.875294	valid_0's binary_logloss: 0.421327
# [77]	valid_0's auc: 0.875279	valid_0's binary_logloss: 0.421299
# [78]	valid_0's auc: 0.875233	valid_0's binary_logloss: 0.421272
# [79]	valid_0's auc: 0.875221	valid_0's binary_logloss: 0.421263
# [80]	valid_0's auc: 0.875193	valid_0's binary_logloss: 0.421235
# [81]	valid_0's auc: 0.87518	valid_0's binary_logloss: 0.421188
# [82]	valid_0's auc: 0.875156	valid_0's binary_logloss: 0.421196
# [83]	valid_0's auc: 0.875175	valid_0's binary_logloss: 0.421169
# [84]	valid_0's auc: 0.875169	valid_0's binary_logloss: 0.42114
# [85]	valid_0's auc: 0.875221	valid_0's binary_logloss: 0.421126
# [86]	valid_0's auc: 0.875258	valid_0's binary_logloss: 0.421113
# [87]	valid_0's auc: 0.875278	valid_0's binary_logloss: 0.421111
# [88]	valid_0's auc: 0.875205	valid_0's binary_logloss: 0.421129
# [89]	valid_0's auc: 0.875188	valid_0's binary_logloss: 0.421088
# [90]	valid_0's auc: 0.875198	valid_0's binary_logloss: 0.421022
# [91]	valid_0's auc: 0.875187	valid_0's binary_logloss: 0.421024
# [92]	valid_0's auc: 0.87516	valid_0's binary_logloss: 0.421006
# [93]	valid_0's auc: 0.875106	valid_0's binary_logloss: 0.421028
# [94]	valid_0's auc: 0.875075	valid_0's binary_logloss: 0.421025
# [95]	valid_0's auc: 0.875083	valid_0's binary_logloss: 0.420971
# [96]	valid_0's auc: 0.875044	valid_0's binary_logloss: 0.420964
# [97]	valid_0's auc: 0.875022	valid_0's binary_logloss: 0.420949
# [98]	valid_0's auc: 0.875031	valid_0's binary_logloss: 0.420919
# [99]	valid_0's auc: 0.875004	valid_0's binary_logloss: 0.420902
# [100]	valid_0's auc: 0.87499	valid_0's binary_logloss: 0.420881
# [101]	valid_0's auc: 0.874962	valid_0's binary_logloss: 0.420886
# [102]	valid_0's auc: 0.874993	valid_0's binary_logloss: 0.420875
# [103]	valid_0's auc: 0.874995	valid_0's binary_logloss: 0.42085
# [104]	valid_0's auc: 0.874969	valid_0's binary_logloss: 0.420863
# [105]	valid_0's auc: 0.874949	valid_0's binary_logloss: 0.420848
# [106]	valid_0's auc: 0.874862	valid_0's binary_logloss: 0.420867
# [107]	valid_0's auc: 0.874848	valid_0's binary_logloss: 0.420864
# [108]	valid_0's auc: 0.874831	valid_0's binary_logloss: 0.420853
# [109]	valid_0's auc: 0.874825	valid_0's binary_logloss: 0.420826
# [110]	valid_0's auc: 0.874836	valid_0's binary_logloss: 0.420828
# [111]	valid_0's auc: 0.87484	valid_0's binary_logloss: 0.420823
# [112]	valid_0's auc: 0.874869	valid_0's binary_logloss: 0.420774
# [113]	valid_0's auc: 0.874887	valid_0's binary_logloss: 0.420746
# [114]	valid_0's auc: 0.874859	valid_0's binary_logloss: 0.420747
# [115]	valid_0's auc: 0.874764	valid_0's binary_logloss: 0.42076
# [116]	valid_0's auc: 0.87482	valid_0's binary_logloss: 0.420706
# [117]	valid_0's auc: 0.874795	valid_0's binary_logloss: 0.420694
# [118]	valid_0's auc: 0.874804	valid_0's binary_logloss: 0.420655
# [119]	valid_0's auc: 0.874821	valid_0's binary_logloss: 0.42065
# [120]	valid_0's auc: 0.874803	valid_0's binary_logloss: 0.420657
# [121]	valid_0's auc: 0.874804	valid_0's binary_logloss: 0.420633
# [122]	valid_0's auc: 0.874823	valid_0's binary_logloss: 0.42062
# [123]	valid_0's auc: 0.87483	valid_0's binary_logloss: 0.420603
# [124]	valid_0's auc: 0.874849	valid_0's binary_logloss: 0.420567
# [125]	valid_0's auc: 0.874841	valid_0's binary_logloss: 0.420556
# [126]	valid_0's auc: 0.874802	valid_0's binary_logloss: 0.420567
# [127]	valid_0's auc: 0.874826	valid_0's binary_logloss: 0.420565
# [128]	valid_0's auc: 0.874815	valid_0's binary_logloss: 0.42054
# [129]	valid_0's auc: 0.874805	valid_0's binary_logloss: 0.420518
# [130]	valid_0's auc: 0.874799	valid_0's binary_logloss: 0.420487
# [131]	valid_0's auc: 0.874729	valid_0's binary_logloss: 0.420496
# [132]	valid_0's auc: 0.874771	valid_0's binary_logloss: 0.420464
# [133]	valid_0's auc: 0.874792	valid_0's binary_logloss: 0.420409
# [134]	valid_0's auc: 0.874775	valid_0's binary_logloss: 0.420398
# [135]	valid_0's auc: 0.874778	valid_0's binary_logloss: 0.420374
# [136]	valid_0's auc: 0.874787	valid_0's binary_logloss: 0.420345
# [137]	valid_0's auc: 0.874713	valid_0's binary_logloss: 0.420363
# [138]	valid_0's auc: 0.874696	valid_0's binary_logloss: 0.420348
# [139]	valid_0's auc: 0.874665	valid_0's binary_logloss: 0.420335
# [140]	valid_0's auc: 0.874632	valid_0's binary_logloss: 0.420335
# [141]	valid_0's auc: 0.874631	valid_0's binary_logloss: 0.42034
# [142]	valid_0's auc: 0.874633	valid_0's binary_logloss: 0.420315
# [143]	valid_0's auc: 0.874623	valid_0's binary_logloss: 0.420305
# [144]	valid_0's auc: 0.87463	valid_0's binary_logloss: 0.42027
# [145]	valid_0's auc: 0.87459	valid_0's binary_logloss: 0.420262
# [146]	valid_0's auc: 0.874535	valid_0's binary_logloss: 0.420281
# [147]	valid_0's auc: 0.874517	valid_0's binary_logloss: 0.420266
# [148]	valid_0's auc: 0.874493	valid_0's binary_logloss: 0.420281
# [149]	valid_0's auc: 0.87452	valid_0's binary_logloss: 0.420241
# [150]	valid_0's auc: 0.874525	valid_0's binary_logloss: 0.420239
# [151]	valid_0's auc: 0.874522	valid_0's binary_logloss: 0.420223
# [152]	valid_0's auc: 0.874456	valid_0's binary_logloss: 0.420239
# [153]	valid_0's auc: 0.874471	valid_0's binary_logloss: 0.420224
# [154]	valid_0's auc: 0.87446	valid_0's binary_logloss: 0.420239
# [155]	valid_0's auc: 0.874451	valid_0's binary_logloss: 0.420239
# [156]	valid_0's auc: 0.874451	valid_0's binary_logloss: 0.420224
# [157]	valid_0's auc: 0.874383	valid_0's binary_logloss: 0.420233
# [158]	valid_0's auc: 0.874385	valid_0's binary_logloss: 0.420206
# [159]	valid_0's auc: 0.874365	valid_0's binary_logloss: 0.420205
# [160]	valid_0's auc: 0.874372	valid_0's binary_logloss: 0.420189
# [161]	valid_0's auc: 0.874379	valid_0's binary_logloss: 0.420173
# [162]	valid_0's auc: 0.874371	valid_0's binary_logloss: 0.420167
# [163]	valid_0's auc: 0.87438	valid_0's binary_logloss: 0.420139
# [164]	valid_0's auc: 0.874375	valid_0's binary_logloss: 0.420138
# [165]	valid_0's auc: 0.874366	valid_0's binary_logloss: 0.420126
# [166]	valid_0's auc: 0.87434	valid_0's binary_logloss: 0.420129
# [167]	valid_0's auc: 0.874303	valid_0's binary_logloss: 0.420142
# [168]	valid_0's auc: 0.874276	valid_0's binary_logloss: 0.420108
# [169]	valid_0's auc: 0.874251	valid_0's binary_logloss: 0.420117
# [170]	valid_0's auc: 0.874227	valid_0's binary_logloss: 0.420094
# [171]	valid_0's auc: 0.874215	valid_0's binary_logloss: 0.420093
# [172]	valid_0's auc: 0.874163	valid_0's binary_logloss: 0.420086
# [173]	valid_0's auc: 0.874181	valid_0's binary_logloss: 0.420048
# [174]	valid_0's auc: 0.874165	valid_0's binary_logloss: 0.420034
# [175]	valid_0's auc: 0.874181	valid_0's binary_logloss: 0.420012
# [176]	valid_0's auc: 0.874127	valid_0's binary_logloss: 0.420003
# [177]	valid_0's auc: 0.874139	valid_0's binary_logloss: 0.41996
# [178]	valid_0's auc: 0.874104	valid_0's binary_logloss: 0.419964
# [179]	valid_0's auc: 0.874102	valid_0's binary_logloss: 0.419974
# [180]	valid_0's auc: 0.874101	valid_0's binary_logloss: 0.419952
# [181]	valid_0's auc: 0.874094	valid_0's binary_logloss: 0.419942
# [182]	valid_0's auc: 0.874061	valid_0's binary_logloss: 0.419955
# [183]	valid_0's auc: 0.874055	valid_0's binary_logloss: 0.419959
# [184]	valid_0's auc: 0.874042	valid_0's binary_logloss: 0.419961
# [185]	valid_0's auc: 0.87404	valid_0's binary_logloss: 0.419961
# [186]	valid_0's auc: 0.874063	valid_0's binary_logloss: 0.419931
# [187]	valid_0's auc: 0.874059	valid_0's binary_logloss: 0.419915
# [188]	valid_0's auc: 0.874028	valid_0's binary_logloss: 0.419895
# [189]	valid_0's auc: 0.873994	valid_0's binary_logloss: 0.419884
# [190]	valid_0's auc: 0.874002	valid_0's binary_logloss: 0.419873
# [191]	valid_0's auc: 0.874005	valid_0's binary_logloss: 0.419849
# [192]	valid_0's auc: 0.873998	valid_0's binary_logloss: 0.419841
# [193]	valid_0's auc: 0.873957	valid_0's binary_logloss: 0.419847
# [194]	valid_0's auc: 0.873916	valid_0's binary_logloss: 0.419849
# [195]	valid_0's auc: 0.873943	valid_0's binary_logloss: 0.419812
# [196]	valid_0's auc: 0.873945	valid_0's binary_logloss: 0.419789
# [197]	valid_0's auc: 0.873958	valid_0's binary_logloss: 0.419753
# [198]	valid_0's auc: 0.873945	valid_0's binary_logloss: 0.419742
# [199]	valid_0's auc: 0.87393	valid_0's binary_logloss: 0.419735
# [200]	valid_0's auc: 0.873906	valid_0's binary_logloss: 0.419748
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.86833
# [1]	validation_0-auc:0.86930
# [2]	validation_0-auc:0.86933
# [3]	validation_0-auc:0.86964
# [4]	validation_0-auc:0.86992
# [5]	validation_0-auc:0.87051
# [6]	validation_0-auc:0.87097
# [7]	validation_0-auc:0.87129
# [8]	validation_0-auc:0.87139
# [9]	validation_0-auc:0.87153
# [10]	validation_0-auc:0.87164
# [11]	validation_0-auc:0.87181
# [12]	validation_0-auc:0.87239
# [13]	validation_0-auc:0.87252
# [14]	validation_0-auc:0.87299
# [15]	validation_0-auc:0.87314
# [16]	validation_0-auc:0.87321
# [17]	validation_0-auc:0.87334
# [18]	validation_0-auc:0.87339
# [19]	validation_0-auc:0.87351
# [20]	validation_0-auc:0.87371
# [21]	validation_0-auc:0.87376
# [22]	validation_0-auc:0.87383
# [23]	validation_0-auc:0.87393
# [24]	validation_0-auc:0.87420
# [25]	validation_0-auc:0.87437
# [26]	validation_0-auc:0.87448
# [27]	validation_0-auc:0.87460
# [28]	validation_0-auc:0.87463
# [29]	validation_0-auc:0.87471
# [30]	validation_0-auc:0.87477
# [31]	validation_0-auc:0.87486
# [32]	validation_0-auc:0.87491
# [33]	validation_0-auc:0.87498
# [34]	validation_0-auc:0.87508
# [35]	validation_0-auc:0.87523
# [36]	validation_0-auc:0.87536
# [37]	validation_0-auc:0.87545
# [38]	validation_0-auc:0.87559
# [39]	validation_0-auc:0.87551
# [40]	validation_0-auc:0.87554
# [41]	validation_0-auc:0.87549
# [42]	validation_0-auc:0.87552
# [43]	validation_0-auc:0.87559
# [44]	validation_0-auc:0.87557
# [45]	validation_0-auc:0.87556
# [46]	validation_0-auc:0.87557
# [47]	validation_0-auc:0.87555
# [48]	validation_0-auc:0.87547
# [49]	validation_0-auc:0.87544
# [50]	validation_0-auc:0.87557
# [51]	validation_0-auc:0.87557
# [52]	validation_0-auc:0.87549
# [53]	validation_0-auc:0.87553
# [54]	validation_0-auc:0.87543
# [55]	validation_0-auc:0.87550
# [56]	validation_0-auc:0.87553
# [57]	validation_0-auc:0.87551
# [58]	validation_0-auc:0.87548
# [59]	validation_0-auc:0.87544
# [60]	validation_0-auc:0.87545
# [61]	validation_0-auc:0.87543
# [62]	validation_0-auc:0.87538
# [63]	validation_0-auc:0.87535
# [64]	validation_0-auc:0.87537
# [65]	validation_0-auc:0.87541
# [66]	validation_0-auc:0.87542
# [67]	validation_0-auc:0.87545
# [68]	validation_0-auc:0.87544
# [69]	validation_0-auc:0.87544
# [70]	validation_0-auc:0.87545
# [71]	validation_0-auc:0.87543
# [72]	validation_0-auc:0.87541
# [73]	validation_0-auc:0.87539
# [74]	validation_0-auc:0.87541
# [75]	validation_0-auc:0.87539
# [76]	validation_0-auc:0.87546
# [77]	validation_0-auc:0.87547
# [78]	validation_0-auc:0.87544
# [79]	validation_0-auc:0.87538
# [80]	validation_0-auc:0.87540
# [81]	validation_0-auc:0.87542
# [82]	validation_0-auc:0.87541
# [83]	validation_0-auc:0.87542
# [84]	validation_0-auc:0.87540
# [85]	validation_0-auc:0.87538
# [86]	validation_0-auc:0.87533
# [87]	validation_0-auc:0.87531
# [88]	validation_0-auc:0.87528
# [89]	validation_0-auc:0.87529
# [90]	validation_0-auc:0.87531
# [91]	validation_0-auc:0.87531
# [92]	validation_0-auc:0.87534
# [93]	validation_0-auc:0.87534
# [94]	validation_0-auc:0.87534
# [95]	validation_0-auc:0.87535
# [96]	validation_0-auc:0.87535
# [97]	validation_0-auc:0.87535
# [98]	validation_0-auc:0.87532
# [99]	validation_0-auc:0.87535
# ROC_AUC
# ***************************
# 0.8750251239380873
# None

# %%
test_pred1 = np.mean(test_pred, axis=0)

test['Is_Lead'] = test_pred1

test[['ID','Is_Lead']].to_csv('baseline.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.shape
# Out:
# (351037, 320)

# %% [markdown]
# PYCARET
